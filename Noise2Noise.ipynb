# %%
import os,sys,shutil
import tensorflow as tf
import numpy as np
import argparse
import cv2,math,glob,random,time
import time
import matplotlib.pyplot as plt
import numpy as np
import cv2
import glob
import random
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
# Model
REGULARIZER_COF = 1e-6

def _fc_variable( weight_shape,name="fc"):
    with tf.variable_scope(name):
        # check weight_shape
        input_channels  = int(weight_shape[0])
        output_channels = int(weight_shape[1])
        weight_shape    = (input_channels, output_channels)

        # define variables
        weight = tf.get_variable("w", weight_shape     , initializer=tf.contrib.layers.xavier_initializer())
        bias   = tf.get_variable("b", [weight_shape[1]], initializer=tf.constant_initializer(0.0))
    return weight, bias

def _conv_variable( weight_shape,name="conv"):
    with tf.variable_scope(name):
        # check weight_shape
        w = int(weight_shape[0])
        h = int(weight_shape[1])
        input_channels  = int(weight_shape[2])
        output_channels = int(weight_shape[3])
        weight_shape = (w,h,input_channels, output_channels)
        # define variables
        weight = tf.get_variable("w", weight_shape     , initializer=tf.contrib.layers.xavier_initializer_conv2d())
        bias   = tf.get_variable("b", [output_channels], initializer=tf.constant_initializer(0.0))
    return weight, bias

def _deconv_variable( weight_shape,name="conv"):
    with tf.variable_scope(name):
        # check weight_shape
        w = int(weight_shape[0])
        h = int(weight_shape[1])
        output_channels = int(weight_shape[2])
        input_channels  = int(weight_shape[3])
        weight_shape = (w,h,input_channels, output_channels)
        regularizer = tf.contrib.layers.l2_regularizer(scale=REGULARIZER_COF)
        # define variables
        weight = tf.get_variable("w", weight_shape    ,
                                initializer=tf.contrib.layers.xavier_initializer_conv2d(),
                                regularizer=regularizer)
        bias   = tf.get_variable("b", [input_channels], initializer=tf.constant_initializer(0.0))
    return weight, bias

def _conv2d( x, W, stride):
    return tf.nn.conv2d(x, W, strides = [1, stride, stride, 1], padding = "SAME")

def _deconv2d( x, W, output_shape, stride=1):
    # x           : [nBatch, height, width, in_channels]
    # output_shape: [nBatch, height, width, out_channels]
    return tf.nn.conv2d_transpose(x, W, output_shape=output_shape, strides=[1,stride,stride,1], padding = "SAME",data_format="NHWC")


def _conv_layer(x, input_layer, output_layer, stride, filter_size=3, name="conv", isTraining=True):
    conv_w, conv_b = _conv_variable([filter_size,filter_size,input_layer,output_layer],name="conv"+name)
    h = _conv2d(x,conv_w,stride=stride) + conv_b
    h = tf.contrib.layers.batch_norm(h, decay=0.9, updates_collections=None, epsilon=1e-5, scale=True, is_training=isTraining, scope="gNormc"+name)
    h = tf.nn.leaky_relu(h)
    return h

def _deconv_layer(x,input_layer, output_layer, stride=2, filter_size=3, name="deconv", isTraining=True):
    bs, h, w, c = x.get_shape().as_list()
    deconv_w, deconv_b = _deconv_variable([filter_size,filter_size,input_layer,output_layer],name="deconv"+name )
    h = _deconv2d(x,deconv_w, output_shape=[bs,h*2,w*2,output_layer], stride=stride) + deconv_b
    h = tf.contrib.layers.batch_norm(h, decay=0.9, updates_collections=None, epsilon=1e-5, scale=True, is_training=isTraining, scope="gNormd"+name)
    h = tf.nn.leaky_relu(h)
    return h

def buildGenerator(x,reuse=False,isTraining=True,nBatch=64,resBlock=4,name="generator"):

    with tf.variable_scope(name, reuse=reuse) as scope:
        if reuse: scope.reuse_variables()

        h = _conv_layer(x, 3, 64, 1, 7 , "i-1_g")

        tmp = h

        for i in range(resBlock):
            conv_w, conv_b = _conv_variable([3,3,64,64],name="res%s-1" % i)
            nn = _conv2d(h,conv_w,stride=1) + conv_b
            nn = tf.contrib.layers.batch_norm(nn, decay=0.9, updates_collections=None, epsilon=1e-5, scale=True, is_training=isTraining, scope="Normr%s-1_g" %i)
            nn = tf.nn.leaky_relu(nn)
            conv_w, conv_b = _conv_variable([3,3,64,64],name="res%s-2" % i)
            nn = _conv2d(nn,conv_w,stride=1) + conv_b
            nn = tf.contrib.layers.batch_norm(nn, decay=0.9, updates_collections=None, epsilon=1e-5, scale=True, is_training=isTraining, scope="Normr%s-2_g" %i)

            nn = tf.math.add(h,nn, name="resadd%s" % i)
            h = nn

        conv_w, conv_b = _conv_variable([3,3,64,64],name="conv3-1_g" )
        h = _conv2d(h,conv_w,stride=1) + conv_b
        h = tf.contrib.layers.batch_norm(h, decay=0.9, updates_collections=None, epsilon=1e-5, scale=True, is_training=isTraining, scope="Norm3-1_g")
        h = tf.math.add(tmp,h, name="add")

        h = _conv_layer(h, 64, 64, 1, 3 , "3-2_g")


        conv_w, conv_b = _conv_variable([7,7,64,3],name="convo_g" )
        h = _conv2d(h,conv_w,stride=1) + conv_b
        y = tf.nn.tanh(h)

    return y

# %%
# Data Generator
class BatchGenerator:
    def __init__(self, img_size, datadir):
        self.folderPath = datadir
        #self.orgSize = (218,173)
        self.imgSize = (img_size,img_size)
        assert self.imgSize[0]==self.imgSize[1]


    def add_mosaic(self,img,ocp):
        #flg = True
        occupancy = ocp#np.random.uniform(min_occupancy, max_occupancy)
        mosaic =img
        h, w, _ = img.shape
        img_for_cnt = np.zeros((h, w), np.uint8)

        while True:
            ms_size = np.random.randint(8,16)
            scale = np.random.randint(4,8)
            x = random.randint(0, max(0, w - 1 - ms_size))
            y = random.randint(0, h - 1 - ms_size)
            area = img[y:y+ms_size,x:x+ms_size]
            area = cv2.resize(area,(ms_size//scale,ms_size//scale), interpolation=cv2.INTER_NEAREST)
            area = cv2.resize(area,(ms_size,ms_size), interpolation=cv2.INTER_NEAREST)
            mosaic[y:y+ms_size,x:x+ms_size] = area
            area = np.where(area>0, 255, area)
            img_for_cnt[y:y+ms_size,x:x+ms_size] = cv2.cvtColor(area, cv2.COLOR_RGB2GRAY)
            #print((img_for_cnt > 0).sum())
            if (img_for_cnt > 0).sum() > h * w * occupancy:

                break
        return mosaic

    def add_impulse(self, img, ocp):
        rate = np.random.rand() * ocp/2 + ocp/2
        mask = np.random.binomial(size=img.shape, n=1, p=rate)
        noise = np.random.randint(256, size=img.shape)
        img = img * (1 - mask) + noise * mask
        return img


    def add_noise(self, img, ocp):
        #noise = (np.random.rand(self.imgSize[0],self.imgSize[1],3) -0.5) * 512
        rate = np.random.rand() * ocp/2 + ocp/2
        noise = np.random.normal(0,100,(self.imgSize[0],self.imgSize[1],3))
        occupy = np.random.binomial(n=1,p=rate,size=[self.imgSize[0],self.imgSize[1],3])
        noise = noise * occupy
        img = img+noise
        img = np.clip(img,0,255)
        return img

    def strongNoise(self, img, ntype="gauss"):
        height = img.shape[0]
        width = img.shape[1]
        #print(height,width)
        noise = np.zeros_like(img)

        if ntype == "random":
            noise = (np.random.rand(height,width,3) - 0.5) * 255

        elif ntype == "gauss":
            noise = (np.random.randn(height,width,3) - 0.5) * 255

        elif ntype == "sandp":
            noise = (np.random.rand(height,width) - 0.5) * 255
            noise = np.where( noise > 255/4, 255, 0)
            noise2 =(np.random.rand(height,width) - 0.5) * 255
            noise2 = np.where( noise2 > 255/4, 0, -255)
            noise += noise2
            noise = np.tile(noise,3).reshape(height,width,3)

        new = img + noise
        return new

    def getBatch(self, nBatch, id, subFolder, ocp=0.5):
        x   = np.zeros( (nBatch,self.imgSize[0],self.imgSize[1],3), dtype=np.float32)
        imagePath = glob.glob(self.folderPath + "/" + subFolder + "/*")
        for i,j in enumerate(id):
            if j >= len(imagePath):
                continue
            img = cv2.imread(imagePath[j])
            dmin = min(img.shape[0],img.shape[1])
            img = img[int(0.5*(img.shape[0]-dmin)):int(0.5*(img.shape[0]+dmin)),int(0.5*(img.shape[1]-dmin)):int(0.5*(img.shape[1]+dmin)),:]
            img = cv2.resize(img,self.imgSize)

            #img = self.add_noise(img,ocp)
            #img = self.add_mosaic(img,ocp)
            #img = self.add_impulse(img,ocp)


            x[i,:,:,:] = (img - 127.5) / 127.5 

        return x

# %%
def loss_g(y, t):
    #mse = tf.reduce_mean(tf.square(y - t))
    loss = tf.nn.l2_loss(y-t) + tf.reduce_sum(tf.abs(y-t))
    return loss


def training(loss):
    optimizer = tf.train.AdamOptimizer(learning_rate=0.01,
                                       beta1=0.9,
                                       beta2=0.999)
    train_step = optimizer.minimize(loss)
    return train_step

def tileImage(imgs):
    d = int(math.sqrt(imgs.shape[0]-1))+1
    h = imgs[0].shape[0]
    w = imgs[0].shape[1]
    r = np.zeros((h*d,w*d,3),dtype=np.float32)
    for idx,img in enumerate(imgs):
        idx_y = int(idx/d)
        idx_x = idx-idx_y*d
        r[idx_y*h:(idx_y+1)*h,idx_x*w:(idx_x+1)*w,:] = img
    return r

def foloderLength(folder):
    dir = folder
    paths = os.listdir(dir)
    return len(paths)

def printParam(scope):
    total_parameters = 0
    for variable in tf.trainable_variables(scope=scope):
        # shape is an array of tf.Dimension
        shape = variable.get_shape()
        variable_parameters = 1
        for dim in shape:
            variable_parameters *= dim.value
        total_parameters += variable_parameters
    print("{} has {} parameters".format(scope, total_parameters))

# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /drive

# %%
# !ls "/drive/My Drive/ML_Project"
ROOT_PATH = "/drive/My Drive/ML_Project/"
DATASET_DIR = ROOT_PATH + "data"
VAL_DIR = ROOT_PATH + "val"
SAVE_DIR = ROOT_PATH + "checkpoints"
SVIM_DIR = ROOT_PATH + "samples"
# Out:
# checkpoints  data  Noise2Noise.ipynb  processed  samples  val

# %%
def main():
    if not os.path.exists(SAVE_DIR):
        os.makedirs(SAVE_DIR)
    if not os.path.exists(SVIM_DIR):
        os.makedirs(SVIM_DIR)

    img_size = 256
    bs = 16

    dir = DATASET_DIR
    val = VAL_DIR
    datalen = foloderLength(DATASET_DIR)
    vallen = foloderLength(VAL_DIR)

    # loading images on training
    batch = BatchGenerator(img_size=img_size,datadir=dir)
    val = BatchGenerator(img_size=img_size,datadir=val)

    id = np.random.choice(range(datalen),bs)
    IN_ = tileImage(batch.getBatch(bs,id, 'a')[:4])

    IN_ = (IN_ + 1)*127.5
    cv2.imwrite("input.png",IN_)


    start = time.time()

    x = tf.placeholder(tf.float32, [bs, img_size, img_size, 3])
    t = tf.placeholder(tf.float32, [bs, img_size, img_size, 3])

    y =buildGenerator(x,nBatch=bs)

    loss = loss_g(y, t)
    printParam(scope="generator")

    train_step = training(loss)

    init = tf.global_variables_initializer()
    sess = tf.Session()
    sess.run(init)
    saver = tf.train.Saver()
    summary = tf.summary.merge_all()

    ckpt = tf.train.get_checkpoint_state(SAVE_DIR)

    if ckpt: # checkpointがある場合
        last_model = ckpt.model_checkpoint_path # 最後に保存したmodelへのパス
        print ("load " + last_model)
        saver.restore(sess, last_model) # 変数データの読み込み
        print("succeed restore model")
    else:
        print("models were not found")
        init = tf.global_variables_initializer()
        sess.run(init)

    print("%.4e sec took initializing"%(time.time()-start))


    hist =[]


    start = time.time()
    for i in range(100000):
        # loading images on training
        id = np.random.choice(range(datalen),bs)
        batch_images_x = batch.getBatch(bs,id,'a', ocp=0.5,)
        batch_images_t = batch.getBatch(bs,id,'b', ocp=0.5)

        tmp, yloss = sess.run([train_step,loss], feed_dict={
            x: batch_images_x,
            t: batch_images_t
        })

        print("in step %s loss = %.4e" %(i,yloss))
        hist.append(yloss)

        if i %40 ==0:
            id = np.random.choice(range(vallen),bs)
            batch_images_x = val.getBatch(bs,id,'a',ocp=0.5)
            out = sess.run(y,feed_dict={
                x:batch_images_x})
            X_ = tileImage(batch_images_x[:4])
            Y_ = tileImage(out[:4])

            X_ = (X_ + 1)*127.5
            Y_ = (Y_ + 1)*127.5
            Z_ = np.concatenate((X_,Y_), axis=1)
            #print(np.max(X_))
            cv2.imwrite("{}/{}.png".format(SVIM_DIR,i),Z_)

            fig = plt.figure()
            ax = fig.add_subplot(111)
            plt.title("Loss")
            plt.grid(which="both")
            plt.yscale("log")
            ax.plot(hist,label="test", linewidth = 0.5)
            plt.savefig("hist.png")
            plt.close()

            print("%.4e sec took per 100steps" %(time.time()-start))
            start = time.time()

        if i%40==0 and i > 10 :
            if i>1900:
                loss_1k_old = np.mean(hist[-2000:-1000])
                loss_1k_new = np.mean(hist[-1000:])
                print("old loss=%.4e , new loss=%.4e"%(loss_1k_old,loss_1k_new))
                if loss_1k_old*2 < loss_1k_new:
                    break

            saver.save(sess,os.path.join(SAVE_DIR,"model.ckpt"),i)

# %%
main()
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# generator has 389571 parameters
# load /drive/My Drive/ML_Project/checkpoints/model.ckpt-25000
# INFO:tensorflow:Restoring parameters from /drive/My Drive/ML_Project/checkpoints/model.ckpt-25000
# succeed restore model
# 8.1891e+00 sec took initializing
# in step 0 loss = 1.6079e+06
# 6.7642e+00 sec took per 100steps
# in step 1 loss = 1.1036e+06
# in step 2 loss = 9.5873e+05
# in step 3 loss = 6.8545e+05
# in step 4 loss = 1.0840e+06
# in step 5 loss = 9.6718e+05
# in step 6 loss = 1.1877e+06
# in step 7 loss = 6.2766e+05
# in step 8 loss = 1.1945e+06
# in step 9 loss = 6.7328e+05
# in step 10 loss = 1.6479e+06
# in step 11 loss = 1.1661e+06
# in step 12 loss = 9.8890e+05
# in step 13 loss = 6.0942e+05
# in step 14 loss = 7.7093e+05
# in step 15 loss = 8.7328e+05
# in step 16 loss = 8.8817e+05
# in step 17 loss = 8.7388e+05
# in step 18 loss = 1.0264e+06
# in step 19 loss = 8.5732e+05
# in step 20 loss = 7.6908e+05
# in step 21 loss = 7.8548e+05
# in step 22 loss = 1.2466e+06
# in step 23 loss = 7.8495e+05
# in step 24 loss = 1.6087e+06
# in step 25 loss = 1.1821e+06
# in step 26 loss = 7.6307e+05
# in step 27 loss = 1.3741e+06
# in step 28 loss = 1.8138e+06
# in step 29 loss = 1.0073e+06
# in step 30 loss = 1.5063e+06
# in step 31 loss = 1.1479e+06
# in step 32 loss = 1.2220e+06
# in step 33 loss = 1.2250e+06
# in step 34 loss = 8.2362e+05
# in step 35 loss = 9.9400e+05
# in step 36 loss = 1.5530e+06
# in step 37 loss = 8.0996e+05
# in step 38 loss = 9.2536e+05
# in step 39 loss = 8.3976e+05
# in step 40 loss = 8.6985e+05
# 2.6340e+01 sec took per 100steps
# in step 41 loss = 9.2895e+05
# in step 42 loss = 6.8625e+05
# in step 43 loss = 6.8624e+05
# in step 44 loss = 6.9884e+05
# in step 45 loss = 6.0777e+05
# in step 46 loss = 6.7212e+05
# in step 47 loss = 8.9566e+05
# in step 48 loss = 8.7705e+05
# in step 49 loss = 4.6593e+05
# in step 50 loss = 6.4016e+05
# in step 51 loss = 5.1842e+05
# in step 52 loss = 4.8911e+05
# in step 53 loss = 5.4717e+05
# in step 54 loss = 5.9557e+05
# in step 55 loss = 5.7878e+05
# in step 56 loss = 4.1426e+05
# in step 57 loss = 4.6527e+05
# in step 58 loss = 4.9301e+05
# in step 59 loss = 3.8547e+05
# in step 60 loss = 3.5502e+05
# in step 61 loss = 4.3316e+05
# in step 62 loss = 4.3123e+05
# in step 63 loss = 4.4935e+05
# in step 64 loss = 5.2313e+05
# in step 65 loss = 4.7679e+05
# in step 66 loss = 6.5770e+05
# in step 67 loss = 4.3625e+05
# in step 68 loss = 4.8580e+05
# in step 69 loss = 5.7875e+05
# in step 70 loss = 5.8568e+05
# in step 71 loss = 5.3800e+05
# in step 72 loss = 6.3906e+05
# in step 73 loss = 6.8544e+05
# in step 74 loss = 6.8935e+05
# in step 75 loss = 5.1262e+05
# in step 76 loss = 4.4689e+05
# in step 77 loss = 4.9180e+05
# in step 78 loss = 5.8265e+05
# in step 79 loss = 4.0410e+05
# in step 80 loss = 4.4352e+05
# 2.6695e+01 sec took per 100steps
# in step 81 loss = 5.3765e+05
# in step 82 loss = 4.3984e+05
# in step 83 loss = 4.2335e+05
# in step 84 loss = 4.3945e+05
# in step 85 loss = 4.1939e+05
# in step 86 loss = 3.2981e+05
# in step 87 loss = 4.3089e+05
# in step 88 loss = 3.5401e+05
# in step 89 loss = 2.6351e+05
# in step 90 loss = 4.1971e+05
# in step 91 loss = 3.6085e+05
# in step 92 loss = 3.9141e+05
# in step 93 loss = 4.2002e+05
# in step 94 loss = 4.2429e+05
# in step 95 loss = 4.0517e+05
# in step 96 loss = 3.4651e+05
# in step 97 loss = 3.8211e+05
# in step 98 loss = 3.1638e+05
# in step 99 loss = 3.7324e+05
# in step 100 loss = 3.6744e+05
# in step 101 loss = 4.5793e+05
# in step 102 loss = 4.6104e+05
# in step 103 loss = 3.4033e+05
# in step 104 loss = 3.1538e+05
# in step 105 loss = 3.0282e+05
# in step 106 loss = 2.8345e+05
# in step 107 loss = 3.7217e+05
# in step 108 loss = 3.4534e+05
# in step 109 loss = 3.0990e+05
# in step 110 loss = 3.3437e+05
# in step 111 loss = 3.1108e+05
# in step 112 loss = 3.1298e+05
# in step 113 loss = 2.0825e+05
# in step 114 loss = 4.3051e+05
# in step 115 loss = 4.0377e+05
# in step 116 loss = 3.6110e+05
# in step 117 loss = 3.8138e+05
# in step 118 loss = 3.6424e+05
# in step 119 loss = 3.1074e+05
# in step 120 loss = 3.5297e+05
# 2.6717e+01 sec took per 100steps
# in step 121 loss = 3.4103e+05
# in step 122 loss = 3.2118e+05
# in step 123 loss = 2.4868e+05
# in step 124 loss = 4.2093e+05
# in step 125 loss = 2.5707e+05
# in step 126 loss = 3.6398e+05
# in step 127 loss = 3.9080e+05
# in step 128 loss = 2.9382e+05
# in step 129 loss = 3.7199e+05
# in step 130 loss = 4.6308e+05
# in step 131 loss = 2.4198e+05
# in step 132 loss = 3.0961e+05
# in step 133 loss = 3.0158e+05
# in step 134 loss = 4.0812e+05
# in step 135 loss = 2.7320e+05
# in step 136 loss = 2.9824e+05
# in step 137 loss = 2.9604e+05
# in step 138 loss = 2.4396e+05
# in step 139 loss = 2.7218e+05
# in step 140 loss = 2.4187e+05
# in step 141 loss = 3.8941e+05
# in step 142 loss = 3.1040e+05
# in step 143 loss = 2.3755e+05
# in step 144 loss = 4.6246e+05
# in step 145 loss = 3.8100e+05
# in step 146 loss = 2.3804e+05
# in step 147 loss = 3.2222e+05
# in step 148 loss = 3.9004e+05
# in step 149 loss = 3.5721e+05
# in step 150 loss = 4.2933e+05
# in step 151 loss = 2.3927e+05
# in step 152 loss = 4.4307e+05
# in step 153 loss = 3.4757e+05
# in step 154 loss = 3.2899e+05
# in step 155 loss = 2.6534e+05
# in step 156 loss = 4.1023e+05
# in step 157 loss = 3.9843e+05
# in step 158 loss = 3.4303e+05
# in step 159 loss = 4.0760e+05
# in step 160 loss = 3.9404e+05
# 2.6525e+01 sec took per 100steps
# in step 161 loss = 3.3374e+05
# in step 162 loss = 4.6296e+05
# in step 163 loss = 4.4577e+05
# in step 164 loss = 3.8149e+05
# in step 165 loss = 3.1569e+05
# in step 166 loss = 3.4800e+05
# in step 167 loss = 3.4629e+05
# in step 168 loss = 2.7056e+05
# in step 169 loss = 2.9468e+05
# in step 170 loss = 2.7072e+05
# in step 171 loss = 3.7672e+05
# in step 172 loss = 3.4169e+05
# in step 173 loss = 2.5175e+05
# in step 174 loss = 3.5953e+05
# in step 175 loss = 3.2516e+05
# in step 176 loss = 2.8126e+05
# in step 177 loss = 2.3220e+05
# in step 178 loss = 4.1862e+05
# in step 179 loss = 2.5704e+05
# in step 180 loss = 2.5391e+05
# in step 181 loss = 2.2513e+05
# in step 182 loss = 2.5168e+05
# in step 183 loss = 2.8038e+05
# in step 184 loss = 3.6570e+05
# in step 185 loss = 3.1354e+05
# in step 186 loss = 3.3712e+05
# in step 187 loss = 3.0423e+05
# in step 188 loss = 2.7768e+05
# in step 189 loss = 2.7855e+05
# in step 190 loss = 3.0279e+05
# in step 191 loss = 2.7962e+05
# in step 192 loss = 2.1435e+05
# in step 193 loss = 2.8629e+05
# in step 194 loss = 2.8895e+05
# in step 195 loss = 3.3611e+05
# in step 196 loss = 3.1986e+05
# in step 197 loss = 4.2025e+05
# in step 198 loss = 3.1077e+05
# in step 199 loss = 3.9772e+05
# in step 200 loss = 2.7917e+05
# 2.6459e+01 sec took per 100steps
# in step 201 loss = 3.3038e+05
# in step 202 loss = 3.2988e+05
# in step 203 loss = 2.8339e+05
# in step 204 loss = 2.7044e+05
# in step 205 loss = 3.4032e+05
# in step 206 loss = 1.7636e+05
# in step 207 loss = 3.7460e+05
# in step 208 loss = 3.3471e+05
# in step 209 loss = 3.1532e+05
# in step 210 loss = 2.6345e+05
# in step 211 loss = 3.3346e+05
# in step 212 loss = 3.4188e+05
# in step 213 loss = 2.9885e+05
# in step 214 loss = 2.8573e+05
# in step 215 loss = 3.2602e+05
# in step 216 loss = 2.4876e+05
# in step 217 loss = 2.2184e+05
# in step 218 loss = 3.5107e+05
# in step 219 loss = 2.7132e+05
# in step 220 loss = 3.0487e+05
# in step 221 loss = 4.1550e+05
# in step 222 loss = 3.0699e+05
# in step 223 loss = 3.7960e+05
# in step 224 loss = 3.2446e+05
# in step 225 loss = 2.3377e+05
# in step 226 loss = 3.0302e+05
# in step 227 loss = 3.2823e+05
# in step 228 loss = 3.2110e+05
# in step 229 loss = 4.1025e+05
# in step 230 loss = 3.3666e+05
# in step 231 loss = 3.0309e+05
# in step 232 loss = 2.9739e+05
# in step 233 loss = 2.4953e+05
# in step 234 loss = 3.0309e+05
# in step 235 loss = 2.4938e+05
# in step 236 loss = 2.9587e+05
# in step 237 loss = 3.4594e+05
# in step 238 loss = 3.7597e+05
# in step 239 loss = 3.1825e+05
# in step 240 loss = 2.7450e+05
# 2.6514e+01 sec took per 100steps
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# in step 241 loss = 3.4798e+05
# in step 242 loss = 4.4518e+05
# in step 243 loss = 3.7096e+05
# in step 244 loss = 3.0288e+05
# in step 245 loss = 2.5774e+05
# in step 246 loss = 3.4331e+05
# in step 247 loss = 3.8511e+05
# in step 248 loss = 2.6604e+05
# in step 249 loss = 2.8560e+05
# in step 250 loss = 3.0285e+05
# in step 251 loss = 3.4599e+05
# in step 252 loss = 3.2267e+05
# in step 253 loss = 2.9275e+05
# in step 254 loss = 2.9196e+05
# in step 255 loss = 2.9229e+05
# in step 256 loss = 2.6545e+05
# in step 257 loss = 2.3919e+05
# in step 258 loss = 3.2906e+05
# in step 259 loss = 3.7993e+05
# in step 260 loss = 3.4861e+05
# in step 261 loss = 2.8042e+05
# in step 262 loss = 2.3259e+05
# in step 263 loss = 3.3930e+05
# in step 264 loss = 2.6201e+05
# in step 265 loss = 3.5468e+05
# in step 266 loss = 3.0328e+05
# in step 267 loss = 3.3843e+05
# in step 268 loss = 3.4547e+05
# in step 269 loss = 4.0428e+05
# in step 270 loss = 3.2139e+05
# in step 271 loss = 2.0581e+05
# in step 272 loss = 1.9606e+05
# in step 273 loss = 3.9924e+05
# in step 274 loss = 2.1539e+05
# in step 275 loss = 2.6532e+05
# in step 276 loss = 2.4202e+05
# in step 277 loss = 2.9054e+05
# in step 278 loss = 2.3763e+05
# in step 279 loss = 2.6235e+05
# in step 280 loss = 2.1386e+05
# 2.6510e+01 sec took per 100steps
# in step 281 loss = 2.8873e+05
# in step 282 loss = 3.1264e+05
# in step 283 loss = 3.6424e+05
# in step 284 loss = 3.1552e+05
# in step 285 loss = 2.9220e+05
# in step 286 loss = 3.1184e+05
# in step 287 loss = 3.1305e+05
# in step 288 loss = 3.1280e+05
# in step 289 loss = 3.3834e+05
# in step 290 loss = 2.6737e+05
# in step 291 loss = 2.8536e+05
# in step 292 loss = 3.6901e+05
# in step 293 loss = 3.0931e+05
# in step 294 loss = 2.8580e+05
# in step 295 loss = 2.2169e+05
# in step 296 loss = 2.3662e+05
# in step 297 loss = 3.2421e+05
# in step 298 loss = 3.4389e+05
# in step 299 loss = 2.8779e+05
# in step 300 loss = 2.9291e+05
# in step 301 loss = 3.0862e+05
# in step 302 loss = 2.8460e+05
# in step 303 loss = 2.3703e+05
# in step 304 loss = 3.4177e+05
# in step 305 loss = 3.6339e+05
# in step 306 loss = 3.1217e+05
# in step 307 loss = 3.3712e+05
# in step 308 loss = 2.4617e+05
# in step 309 loss = 2.3739e+05
# in step 310 loss = 2.4132e+05
# in step 311 loss = 3.2128e+05
# in step 312 loss = 2.6510e+05
# in step 313 loss = 3.3810e+05
# in step 314 loss = 2.2368e+05
# in step 315 loss = 3.1548e+05
# in step 316 loss = 2.9086e+05
# in step 317 loss = 3.3871e+05
# in step 318 loss = 2.6533e+05
# in step 319 loss = 3.3701e+05
# in step 320 loss = 3.3182e+05
# 2.6861e+01 sec took per 100steps
# in step 321 loss = 2.8102e+05
# in step 322 loss = 2.8238e+05
# in step 323 loss = 2.8275e+05
# in step 324 loss = 2.8111e+05
# in step 325 loss = 2.1384e+05
# in step 326 loss = 3.0732e+05
# in step 327 loss = 3.0797e+05
# in step 328 loss = 4.2126e+05
# in step 329 loss = 2.8598e+05
# in step 330 loss = 3.0920e+05
# in step 331 loss = 3.3285e+05
# in step 332 loss = 3.8743e+05
# in step 333 loss = 2.0497e+05
# in step 334 loss = 3.0682e+05
# in step 335 loss = 2.5883e+05
# in step 336 loss = 2.1228e+05
# in step 337 loss = 2.5937e+05
# in step 338 loss = 1.8991e+05
# in step 339 loss = 3.0829e+05
# in step 340 loss = 2.8097e+05
# in step 341 loss = 3.0536e+05
# in step 342 loss = 4.1077e+05
# in step 343 loss = 3.3061e+05
# in step 344 loss = 3.0825e+05
# in step 345 loss = 2.8163e+05
# in step 346 loss = 3.0503e+05
# in step 347 loss = 3.5984e+05
# in step 348 loss = 2.1313e+05
# in step 349 loss = 2.3244e+05
# in step 350 loss = 2.8000e+05
# in step 351 loss = 2.1066e+05
# in step 352 loss = 2.7698e+05
# in step 353 loss = 3.0251e+05
# in step 354 loss = 2.0945e+05
# in step 355 loss = 3.2668e+05
# in step 356 loss = 2.7577e+05
# in step 357 loss = 3.2561e+05
# in step 358 loss = 2.7829e+05
# in step 359 loss = 3.4999e+05
# in step 360 loss = 4.0324e+05
# 2.6238e+01 sec took per 100steps
# in step 361 loss = 3.4871e+05
# in step 362 loss = 2.3947e+05
# in step 363 loss = 2.9954e+05
# in step 364 loss = 2.3006e+05
# in step 365 loss = 3.5834e+05
# in step 366 loss = 3.0161e+05
# in step 367 loss = 2.9998e+05
# in step 368 loss = 2.7837e+05
# in step 369 loss = 3.7442e+05
# in step 370 loss = 2.5596e+05
# in step 371 loss = 2.3136e+05
# in step 372 loss = 3.0232e+05
# in step 373 loss = 2.2999e+05
# in step 374 loss = 2.2931e+05
# in step 375 loss = 2.5255e+05
# in step 376 loss = 2.2833e+05
# in step 377 loss = 2.9868e+05
# in step 378 loss = 2.2808e+05
# in step 379 loss = 2.7545e+05
# in step 380 loss = 2.4983e+05
# in step 381 loss = 1.7009e+05
# in step 382 loss = 2.8402e+05
# in step 383 loss = 2.6248e+05
# in step 384 loss = 2.1193e+05
# in step 385 loss = 4.1815e+05
# in step 386 loss = 2.8465e+05
# in step 387 loss = 2.1777e+05
# in step 388 loss = 3.1108e+05
# in step 389 loss = 2.1058e+05
# in step 390 loss = 2.5393e+05
# in step 391 loss = 1.6623e+05
# in step 392 loss = 3.1283e+05
# in step 393 loss = 2.8316e+05
# in step 394 loss = 2.7883e+05
# in step 395 loss = 1.6718e+05
# in step 396 loss = 3.5667e+05
# in step 397 loss = 2.7714e+05
# in step 398 loss = 2.3078e+05
# in step 399 loss = 2.7747e+05
# in step 400 loss = 2.7566e+05
# 2.6590e+01 sec took per 100steps
# in step 401 loss = 2.7520e+05
# in step 402 loss = 2.2694e+05
# in step 403 loss = 2.7434e+05
# in step 404 loss = 2.7474e+05
# in step 405 loss = 3.2432e+05
# in step 406 loss = 2.7343e+05
# in step 407 loss = 3.2186e+05
# in step 408 loss = 2.5238e+05
# in step 409 loss = 2.9782e+05
# in step 410 loss = 2.7174e+05
# in step 411 loss = 2.7281e+05
# in step 412 loss = 2.0646e+05
# in step 413 loss = 2.9860e+05
# in step 414 loss = 2.2624e+05
# in step 415 loss = 1.6245e+05
# in step 416 loss = 2.7259e+05
# in step 417 loss = 3.2079e+05
# in step 418 loss = 2.2668e+05
# in step 419 loss = 2.0240e+05
# in step 420 loss = 2.2645e+05
# in step 421 loss = 2.9902e+05
# in step 422 loss = 2.7495e+05
# in step 423 loss = 1.6470e+05
# in step 424 loss = 2.2792e+05
# in step 425 loss = 2.8027e+05
# in step 426 loss = 3.4790e+05
# in step 427 loss = 3.0475e+05
# in step 428 loss = 3.9586e+05
# in step 429 loss = 2.5676e+05
# in step 430 loss = 2.3353e+05
# in step 431 loss = 2.2817e+05
# in step 432 loss = 3.2490e+05
# in step 433 loss = 2.5767e+05
# in step 434 loss = 3.2223e+05
# in step 435 loss = 2.7390e+05
# in step 436 loss = 2.7569e+05
# in step 437 loss = 2.7565e+05
# in step 438 loss = 3.7397e+05
# in step 439 loss = 3.0440e+05
# in step 440 loss = 2.3965e+05
# 2.6522e+01 sec took per 100steps
# in step 441 loss = 3.5231e+05
# in step 442 loss = 2.2902e+05
# in step 443 loss = 1.8147e+05
# in step 444 loss = 2.7013e+05
# in step 445 loss = 2.7045e+05
# in step 446 loss = 2.0734e+05
# in step 447 loss = 3.4703e+05
# in step 448 loss = 3.4577e+05
# in step 449 loss = 2.4958e+05
# in step 450 loss = 2.4965e+05
# in step 451 loss = 3.1687e+05
# in step 452 loss = 2.0235e+05
# in step 453 loss = 2.0159e+05
# in step 454 loss = 2.6872e+05
# in step 455 loss = 2.2504e+05
# in step 456 loss = 2.9194e+05
# in step 457 loss = 3.1666e+05
# in step 458 loss = 2.9209e+05
# in step 459 loss = 2.6898e+05
# in step 460 loss = 3.1469e+05
# in step 461 loss = 3.3991e+05
# in step 462 loss = 2.4660e+05
# in step 463 loss = 2.2279e+05
# in step 464 loss = 2.4432e+05
# in step 465 loss = 2.4501e+05
# in step 466 loss = 2.9143e+05
# in step 467 loss = 2.8842e+05
# in step 468 loss = 3.3623e+05
# in step 469 loss = 2.2688e+05
# in step 470 loss = 2.0384e+05
# in step 471 loss = 2.9215e+05
# in step 472 loss = 2.0036e+05
# in step 473 loss = 3.1579e+05
# in step 474 loss = 2.4433e+05
# in step 475 loss = 2.2262e+05
# in step 476 loss = 2.4662e+05
# in step 477 loss = 2.4390e+05
# in step 478 loss = 2.6563e+05
# in step 479 loss = 2.2283e+05
# in step 480 loss = 2.6729e+05
# 2.6610e+01 sec took per 100steps
# in step 481 loss = 2.4432e+05
# in step 482 loss = 2.6639e+05
# in step 483 loss = 1.9985e+05
# in step 484 loss = 2.6511e+05
# in step 485 loss = 1.9816e+05
# in step 486 loss = 3.1425e+05
# in step 487 loss = 2.8696e+05
# in step 488 loss = 2.2124e+05
# in step 489 loss = 1.9836e+05
# in step 490 loss = 2.6417e+05
# in step 491 loss = 3.6679e+05
# in step 492 loss = 2.4184e+05
# in step 493 loss = 2.2168e+05
# in step 494 loss = 3.3768e+05
# in step 495 loss = 2.4446e+05
# in step 496 loss = 2.6379e+05
# in step 497 loss = 3.1145e+05
# in step 498 loss = 2.1910e+05
# in step 499 loss = 2.8735e+05
# in step 500 loss = 3.6211e+05
# in step 501 loss = 2.4302e+05
# in step 502 loss = 3.1174e+05
# in step 503 loss = 2.6578e+05
# in step 504 loss = 2.2123e+05
# in step 505 loss = 2.6425e+05
# in step 506 loss = 3.3625e+05
# in step 507 loss = 2.2003e+05
# in step 508 loss = 2.4211e+05
# in step 509 loss = 2.6304e+05
# in step 510 loss = 2.1970e+05
# in step 511 loss = 2.6345e+05
# in step 512 loss = 3.0917e+05
# in step 513 loss = 2.8477e+05
# in step 514 loss = 2.8522e+05
# in step 515 loss = 2.1808e+05
# in step 516 loss = 2.8360e+05
# in step 517 loss = 3.5737e+05
# in step 518 loss = 2.8336e+05
# in step 519 loss = 2.1928e+05
# in step 520 loss = 2.1824e+05
# 2.6287e+01 sec took per 100steps
# in step 521 loss = 2.6109e+05
# in step 522 loss = 1.7931e+05
# in step 523 loss = 2.8440e+05
# in step 524 loss = 3.5583e+05
# in step 525 loss = 2.3908e+05
# in step 526 loss = 3.7970e+05
# in step 527 loss = 2.8392e+05
# in step 528 loss = 3.0403e+05
# in step 529 loss = 2.3836e+05
# in step 530 loss = 3.5671e+05
# in step 531 loss = 2.5998e+05
# in step 532 loss = 2.5954e+05
# in step 533 loss = 2.8063e+05
# in step 534 loss = 2.0039e+05
# in step 535 loss = 1.8007e+05
# in step 536 loss = 2.3933e+05
# in step 537 loss = 2.8329e+05
# in step 538 loss = 2.8280e+05
# in step 539 loss = 2.3750e+05
# in step 540 loss = 2.1715e+05
# in step 541 loss = 2.3846e+05
# in step 542 loss = 2.1743e+05
# in step 543 loss = 1.9539e+05
# in step 544 loss = 3.1325e+05
# in step 545 loss = 2.8356e+05
# in step 546 loss = 2.1931e+05
# in step 547 loss = 2.8271e+05
# in step 548 loss = 1.9615e+05
# in step 549 loss = 3.0591e+05
# in step 550 loss = 2.8230e+05
# in step 551 loss = 2.5830e+05
# in step 552 loss = 2.5921e+05
# in step 553 loss = 2.5873e+05
# in step 554 loss = 2.7995e+05
# in step 555 loss = 1.5873e+05
# in step 556 loss = 2.1847e+05
# in step 557 loss = 3.3941e+05
# in step 558 loss = 2.4625e+05
# in step 559 loss = 2.6327e+05
# in step 560 loss = 1.7523e+05
# 2.6421e+01 sec took per 100steps
# in step 561 loss = 2.2413e+05
# in step 562 loss = 3.3672e+05
# in step 563 loss = 2.9433e+05
# in step 564 loss = 2.6858e+05
# in step 565 loss = 3.3868e+05
# in step 566 loss = 2.1842e+05
# in step 567 loss = 2.3807e+05
# in step 568 loss = 2.8096e+05
# in step 569 loss = 3.2897e+05
# in step 570 loss = 3.2787e+05
# in step 571 loss = 3.0583e+05
# in step 572 loss = 2.6086e+05
# in step 573 loss = 3.2974e+05
# in step 574 loss = 3.0714e+05
# in step 575 loss = 1.9695e+05
# in step 576 loss = 2.8377e+05
# in step 577 loss = 3.0266e+05
# in step 578 loss = 2.2017e+05
# in step 579 loss = 2.8032e+05
# in step 580 loss = 2.1625e+05
# in step 581 loss = 4.1574e+05
# in step 582 loss = 2.6296e+05
# in step 583 loss = 3.3755e+05
# in step 584 loss = 2.2633e+05
# in step 585 loss = 2.2015e+05
# in step 586 loss = 2.6807e+05
# in step 587 loss = 3.3729e+05
# in step 588 loss = 3.2693e+05
# in step 589 loss = 3.5170e+05
# in step 590 loss = 2.2869e+05
# in step 591 loss = 2.4731e+05
# in step 592 loss = 3.3812e+05
# in step 593 loss = 2.2209e+05
# in step 594 loss = 2.0276e+05
# in step 595 loss = 2.8592e+05
# in step 596 loss = 2.3986e+05
# in step 597 loss = 2.8412e+05
# in step 598 loss = 2.8349e+05
# in step 599 loss = 2.8140e+05
# in step 600 loss = 3.0348e+05
# 2.6548e+01 sec took per 100steps
# in step 601 loss = 1.9812e+05
# in step 602 loss = 3.1817e+05
# in step 603 loss = 2.8191e+05
# in step 604 loss = 2.4386e+05
# in step 605 loss = 3.0797e+05
# in step 606 loss = 2.4081e+05
# in step 607 loss = 1.9908e+05
# in step 608 loss = 2.6300e+05
# in step 609 loss = 1.9826e+05
# in step 610 loss = 2.1469e+05
# in step 611 loss = 2.5861e+05
# in step 612 loss = 3.5091e+05
# in step 613 loss = 3.0025e+05
# in step 614 loss = 1.9685e+05
# in step 615 loss = 3.2883e+05
# in step 616 loss = 2.3423e+05
# in step 617 loss = 3.0199e+05
# in step 618 loss = 2.7688e+05
# in step 619 loss = 2.3556e+05
# in step 620 loss = 2.7850e+05
# in step 621 loss = 3.2215e+05
# in step 622 loss = 2.7705e+05
# in step 623 loss = 2.5455e+05
# in step 624 loss = 2.1307e+05
# in step 625 loss = 2.3430e+05
# in step 626 loss = 3.2084e+05
# in step 627 loss = 2.7733e+05
# in step 628 loss = 2.3440e+05
# in step 629 loss = 1.5961e+05
# in step 630 loss = 2.5953e+05
# in step 631 loss = 2.7674e+05
# in step 632 loss = 2.4055e+05
# in step 633 loss = 2.1350e+05
# in step 634 loss = 2.4025e+05
# in step 635 loss = 2.6084e+05
# in step 636 loss = 2.5462e+05
# in step 637 loss = 2.4088e+05
# in step 638 loss = 2.9926e+05
# in step 639 loss = 2.7616e+05
# in step 640 loss = 2.3288e+05
# 2.6529e+01 sec took per 100steps
# in step 641 loss = 2.3300e+05
# in step 642 loss = 2.9807e+05
# in step 643 loss = 2.5345e+05
# in step 644 loss = 2.2998e+05
# in step 645 loss = 1.9061e+05
# in step 646 loss = 3.2410e+05
# in step 647 loss = 2.1285e+05
# in step 648 loss = 2.9732e+05
# in step 649 loss = 1.9025e+05
# in step 650 loss = 2.9945e+05
# in step 651 loss = 2.0966e+05
# in step 652 loss = 2.0998e+05
# in step 653 loss = 1.7223e+05
# in step 654 loss = 3.1730e+05
# in step 655 loss = 2.9421e+05
# in step 656 loss = 1.7128e+05
# in step 657 loss = 2.7201e+05
# in step 658 loss = 2.4857e+05
# in step 659 loss = 2.4969e+05
# in step 660 loss = 2.6992e+05
# in step 661 loss = 2.9152e+05
# in step 662 loss = 2.2913e+05
# in step 663 loss = 2.0909e+05
# in step 664 loss = 2.4934e+05
# in step 665 loss = 2.4791e+05
# in step 666 loss = 2.6897e+05
# in step 667 loss = 2.6815e+05
# in step 668 loss = 3.1392e+05
# in step 669 loss = 3.3721e+05
# in step 670 loss = 2.6896e+05
# in step 671 loss = 3.1397e+05
# in step 672 loss = 2.2879e+05
# in step 673 loss = 2.2770e+05
# in step 674 loss = 2.6906e+05
# in step 675 loss = 2.2727e+05
# in step 676 loss = 2.6845e+05
# in step 677 loss = 1.9145e+05
# in step 678 loss = 2.8973e+05
# in step 679 loss = 2.0813e+05
# in step 680 loss = 2.6768e+05
# 2.6409e+01 sec took per 100steps
# in step 681 loss = 3.1153e+05
# in step 682 loss = 2.6566e+05
# in step 683 loss = 2.6653e+05
# in step 684 loss = 3.3514e+05
# in step 685 loss = 2.6939e+05
# in step 686 loss = 2.4780e+05
# in step 687 loss = 2.6663e+05
# in step 688 loss = 2.2713e+05
# in step 689 loss = 2.2692e+05
# in step 690 loss = 2.8697e+05
# in step 691 loss = 2.6950e+05
# in step 692 loss = 1.8794e+05
# in step 693 loss = 2.2649e+05
# in step 694 loss = 1.7086e+05
# in step 695 loss = 2.2426e+05
# in step 696 loss = 1.8776e+05
# in step 697 loss = 2.0542e+05
# in step 698 loss = 1.8639e+05
# in step 699 loss = 2.0455e+05
# in step 700 loss = 2.2329e+05
# in step 701 loss = 2.4444e+05
# in step 702 loss = 3.6262e+05
# in step 703 loss = 2.9142e+05
# in step 704 loss = 2.2815e+05
# in step 705 loss = 3.4165e+05
# in step 706 loss = 2.7078e+05
# in step 707 loss = 3.1075e+05
# in step 708 loss = 2.2948e+05
# in step 709 loss = 2.0759e+05
# in step 710 loss = 2.2851e+05
# in step 711 loss = 2.2490e+05
# in step 712 loss = 1.5786e+05
# in step 713 loss = 2.0429e+05
# in step 714 loss = 2.2632e+05
# in step 715 loss = 2.0441e+05
# in step 716 loss = 2.4672e+05
# in step 717 loss = 2.4349e+05
# in step 718 loss = 2.4363e+05
# in step 719 loss = 2.4377e+05
# in step 720 loss = 2.2281e+05
# 2.6506e+01 sec took per 100steps
# in step 721 loss = 2.6445e+05
# in step 722 loss = 2.8559e+05
# in step 723 loss = 2.0457e+05
# in step 724 loss = 3.0972e+05
# in step 725 loss = 2.1073e+05
# in step 726 loss = 2.4413e+05
# in step 727 loss = 2.0737e+05
# in step 728 loss = 2.4844e+05
# in step 729 loss = 2.6416e+05
# in step 730 loss = 1.9722e+05
# in step 731 loss = 1.8784e+05
# in step 732 loss = 2.1049e+05
# in step 733 loss = 2.6687e+05
# in step 734 loss = 2.1912e+05
# in step 735 loss = 2.4720e+05
# in step 736 loss = 2.5198e+05
# in step 737 loss = 2.8609e+05
# in step 738 loss = 2.9305e+05
# in step 739 loss = 2.2810e+05
# in step 740 loss = 2.5263e+05
# in step 741 loss = 2.2612e+05
# in step 742 loss = 2.2960e+05
# in step 743 loss = 2.2424e+05
# in step 744 loss = 2.2533e+05
# in step 745 loss = 2.6927e+05
# in step 746 loss = 2.4545e+05
# in step 747 loss = 2.6774e+05
# in step 748 loss = 1.8385e+05
# in step 749 loss = 2.9853e+05
# in step 750 loss = 2.4151e+05
# in step 751 loss = 2.4856e+05
# in step 752 loss = 2.6251e+05
# in step 753 loss = 3.6181e+05
# in step 754 loss = 2.4117e+05
# in step 755 loss = 2.2343e+05
# in step 756 loss = 2.2013e+05
# in step 757 loss = 2.8387e+05
# in step 758 loss = 1.9493e+05
# in step 759 loss = 3.1771e+05
# in step 760 loss = 2.4663e+05
# 2.6435e+01 sec took per 100steps
# in step 761 loss = 2.2797e+05
# in step 762 loss = 2.2813e+05
# in step 763 loss = 2.2332e+05
# in step 764 loss = 2.6532e+05
# in step 765 loss = 2.6425e+05
# in step 766 loss = 2.0595e+05
# in step 767 loss = 3.5569e+05
# in step 768 loss = 2.2824e+05
# in step 769 loss = 2.3261e+05
# in step 770 loss = 2.2578e+05
# in step 771 loss = 2.7128e+05
# in step 772 loss = 3.0911e+05
# in step 773 loss = 2.2367e+05
# in step 774 loss = 2.6381e+05
# in step 775 loss = 2.7135e+05
# in step 776 loss = 2.0286e+05
# in step 777 loss = 2.2159e+05
# in step 778 loss = 2.4227e+05
# in step 779 loss = 2.2059e+05
# in step 780 loss = 2.4046e+05
# in step 781 loss = 2.1859e+05
# in step 782 loss = 1.8305e+05
# in step 783 loss = 1.9935e+05
# in step 784 loss = 2.1955e+05
# in step 785 loss = 2.3875e+05
# in step 786 loss = 3.3105e+05
# in step 787 loss = 2.0047e+05
# in step 788 loss = 3.0604e+05
# in step 789 loss = 2.0102e+05
# in step 790 loss = 2.4530e+05
# in step 791 loss = 3.0952e+05
# in step 792 loss = 2.8228e+05
# in step 793 loss = 2.4712e+05
# in step 794 loss = 2.4184e+05
# in step 795 loss = 2.0292e+05
# in step 796 loss = 3.3466e+05
# in step 797 loss = 1.8694e+05
# in step 798 loss = 2.2093e+05
# in step 799 loss = 2.4159e+05
# in step 800 loss = 2.4026e+05
# 2.6790e+01 sec took per 100steps
# in step 801 loss = 2.7966e+05
# in step 802 loss = 2.8332e+05
# in step 803 loss = 2.5627e+05
# in step 804 loss = 2.7978e+05
# in step 805 loss = 3.0176e+05
# in step 806 loss = 2.3722e+05
# in step 807 loss = 2.7976e+05
# in step 808 loss = 2.1816e+05
# in step 809 loss = 2.7567e+05
# in step 810 loss = 1.9985e+05
# in step 811 loss = 2.0014e+05
# in step 812 loss = 2.3463e+05
# in step 813 loss = 2.7578e+05
# in step 814 loss = 2.1515e+05
# in step 815 loss = 1.8085e+05
# in step 816 loss = 2.1708e+05
# in step 817 loss = 1.9714e+05
# in step 818 loss = 2.7600e+05
# in step 819 loss = 2.3436e+05
# in step 820 loss = 1.7988e+05
# in step 821 loss = 1.9783e+05
# in step 822 loss = 2.1492e+05
# in step 823 loss = 2.5488e+05
# in step 824 loss = 2.3522e+05
# in step 825 loss = 2.1336e+05
# in step 826 loss = 2.8008e+05
# in step 827 loss = 2.7346e+05
# in step 828 loss = 2.5862e+05
# in step 829 loss = 2.1453e+05
# in step 830 loss = 2.1870e+05
# in step 831 loss = 2.1651e+05
# in step 832 loss = 2.5291e+05
# in step 833 loss = 2.5642e+05
# in step 834 loss = 2.3187e+05
# in step 835 loss = 2.1580e+05
# in step 836 loss = 2.3518e+05
# in step 837 loss = 2.7315e+05
# in step 838 loss = 2.4107e+05
# in step 839 loss = 2.7371e+05
# in step 840 loss = 2.7561e+05
# 2.6600e+01 sec took per 100steps
# in step 841 loss = 1.8435e+05
# in step 842 loss = 2.1515e+05
# in step 843 loss = 2.3264e+05
# in step 844 loss = 1.9734e+05
# in step 845 loss = 2.9605e+05
# in step 846 loss = 2.1792e+05
# in step 847 loss = 2.9610e+05
# in step 848 loss = 2.5589e+05
# in step 849 loss = 2.3310e+05
# in step 850 loss = 2.3335e+05
# in step 851 loss = 2.7543e+05
# in step 852 loss = 2.3294e+05
# in step 853 loss = 3.1936e+05
# in step 854 loss = 1.8560e+05
# in step 855 loss = 2.5453e+05
# in step 856 loss = 2.4053e+05
# in step 857 loss = 2.5299e+05
# in step 858 loss = 2.7936e+05
# in step 859 loss = 2.3222e+05
# in step 860 loss = 1.6952e+05
# in step 861 loss = 1.5302e+05
# in step 862 loss = 2.3792e+05
# in step 863 loss = 2.5404e+05
# in step 864 loss = 2.5593e+05
# in step 865 loss = 2.5509e+05
# in step 866 loss = 1.6829e+05
# in step 867 loss = 2.3810e+05
# in step 868 loss = 3.0262e+05
# in step 869 loss = 2.4026e+05
# in step 870 loss = 2.1759e+05
# in step 871 loss = 2.3839e+05
# in step 872 loss = 2.7970e+05
# in step 873 loss = 1.8343e+05
# in step 874 loss = 2.3754e+05
# in step 875 loss = 2.3590e+05
# in step 876 loss = 2.3814e+05
# in step 877 loss = 2.7322e+05
# in step 878 loss = 3.2174e+05
# in step 879 loss = 2.3756e+05
# in step 880 loss = 2.3509e+05
# 2.6379e+01 sec took per 100steps
# in step 881 loss = 2.3426e+05
# in step 882 loss = 2.1650e+05
# in step 883 loss = 2.1486e+05
# in step 884 loss = 2.1482e+05
# in step 885 loss = 2.1367e+05
# in step 886 loss = 2.3305e+05
# in step 887 loss = 3.1643e+05
# in step 888 loss = 1.6599e+05
# in step 889 loss = 3.1722e+05
# in step 890 loss = 2.5275e+05
# in step 891 loss = 2.5222e+05
# in step 892 loss = 2.1253e+05
# in step 893 loss = 2.7328e+05
# in step 894 loss = 1.9598e+05
# in step 895 loss = 2.3055e+05
# in step 896 loss = 1.9594e+05
# in step 897 loss = 2.1148e+05
# in step 898 loss = 2.2958e+05
# in step 899 loss = 2.2953e+05
# in step 900 loss = 2.7092e+05
# in step 901 loss = 1.9294e+05
# in step 902 loss = 2.2935e+05
# in step 903 loss = 2.0899e+05
# in step 904 loss = 2.4767e+05
# in step 905 loss = 2.6722e+05
# in step 906 loss = 2.2723e+05
# in step 907 loss = 2.0891e+05
# in step 908 loss = 2.0864e+05
# in step 909 loss = 2.4647e+05
# in step 910 loss = 2.2627e+05
# in step 911 loss = 2.2664e+05
# in step 912 loss = 2.2606e+05
# in step 913 loss = 2.2580e+05
# in step 914 loss = 2.4495e+05
# in step 915 loss = 2.2565e+05
# in step 916 loss = 2.2551e+05
# in step 917 loss = 2.4467e+05
# in step 918 loss = 2.8641e+05
# in step 919 loss = 2.2798e+05
# in step 920 loss = 1.9374e+05
# 2.6430e+01 sec took per 100steps
# in step 921 loss = 2.6871e+05
# in step 922 loss = 2.1125e+05
# in step 923 loss = 2.6616e+05
# in step 924 loss = 2.8835e+05
# in step 925 loss = 2.1031e+05
# in step 926 loss = 1.7740e+05
# in step 927 loss = 1.9293e+05
# in step 928 loss = 1.6051e+05
# in step 929 loss = 2.1087e+05
# in step 930 loss = 2.4663e+05
# in step 931 loss = 2.3112e+05
# in step 932 loss = 2.0873e+05
# in step 933 loss = 2.1040e+05
# in step 934 loss = 2.0746e+05
# in step 935 loss = 2.6705e+05
# in step 936 loss = 2.0758e+05
# in step 937 loss = 2.2952e+05
# in step 938 loss = 2.2609e+05
# in step 939 loss = 2.1002e+05
# in step 940 loss = 2.2679e+05
# in step 941 loss = 1.9027e+05
# in step 942 loss = 2.4446e+05
# in step 943 loss = 2.0809e+05
# in step 944 loss = 2.8947e+05
# in step 945 loss = 2.0713e+05
# in step 946 loss = 2.6459e+05
# in step 947 loss = 1.8988e+05
# in step 948 loss = 2.4500e+05
# in step 949 loss = 2.4516e+05
# in step 950 loss = 2.6426e+05
# in step 951 loss = 3.0787e+05
# in step 952 loss = 1.9268e+05
# in step 953 loss = 1.9243e+05
# in step 954 loss = 2.8475e+05
# in step 955 loss = 3.2870e+05
# in step 956 loss = 1.9329e+05
# in step 957 loss = 1.9375e+05
# in step 958 loss = 2.2783e+05
# in step 959 loss = 2.4701e+05
# in step 960 loss = 1.5599e+05
# 2.6296e+01 sec took per 100steps
# in step 961 loss = 3.4660e+05
# in step 962 loss = 1.9767e+05
# in step 963 loss = 2.6385e+05
# in step 964 loss = 1.7283e+05
# in step 965 loss = 2.0162e+05
# in step 966 loss = 1.7185e+05
# in step 967 loss = 3.3071e+05
# in step 968 loss = 2.1734e+05
# in step 969 loss = 2.0390e+05
# in step 970 loss = 1.8008e+05
# in step 971 loss = 2.1624e+05
# in step 972 loss = 1.9539e+05
# in step 973 loss = 2.9589e+05
# in step 974 loss = 2.3524e+05
# in step 975 loss = 2.9252e+05
# in step 976 loss = 2.1284e+05
# in step 977 loss = 2.5040e+05
# in step 978 loss = 2.4865e+05
# in step 979 loss = 2.3019e+05
# in step 980 loss = 1.7992e+05
# in step 981 loss = 2.1398e+05
# in step 982 loss = 2.1288e+05
# in step 983 loss = 2.9006e+05
# in step 984 loss = 2.9092e+05
# in step 985 loss = 1.8917e+05
# in step 986 loss = 2.7102e+05
# in step 987 loss = 2.3489e+05
# in step 988 loss = 2.2685e+05
# in step 989 loss = 2.9133e+05
# in step 990 loss = 2.6869e+05
# in step 991 loss = 2.1065e+05
# in step 992 loss = 2.2837e+05
# in step 993 loss = 2.9099e+05
# in step 994 loss = 2.2761e+05
# in step 995 loss = 2.4812e+05
# in step 996 loss = 2.4529e+05
# in step 997 loss = 2.4394e+05
# in step 998 loss = 2.2703e+05
# in step 999 loss = 2.4266e+05
# in step 1000 loss = 2.4430e+05
# 2.6419e+01 sec took per 100steps
# in step 1001 loss = 2.4422e+05
# in step 1002 loss = 2.4235e+05
# in step 1003 loss = 2.2510e+05
# in step 1004 loss = 3.0619e+05
# in step 1005 loss = 2.0919e+05
# in step 1006 loss = 2.4298e+05
# in step 1007 loss = 1.8904e+05
# in step 1008 loss = 1.6012e+05
# in step 1009 loss = 2.2598e+05
# in step 1010 loss = 1.7391e+05
# in step 1011 loss = 2.2456e+05
# in step 1012 loss = 2.4181e+05
# in step 1013 loss = 1.8872e+05
# in step 1014 loss = 2.0468e+05
# in step 1015 loss = 2.0565e+05
# in step 1016 loss = 1.8792e+05
# in step 1017 loss = 2.4183e+05
# in step 1018 loss = 2.6079e+05
# in step 1019 loss = 2.0423e+05
# in step 1020 loss = 2.0351e+05
# in step 1021 loss = 1.8695e+05
# in step 1022 loss = 2.6120e+05
# in step 1023 loss = 1.5881e+05
# in step 1024 loss = 2.2172e+05
# in step 1025 loss = 1.8678e+05
# in step 1026 loss = 2.6137e+05
# in step 1027 loss = 2.2151e+05
# in step 1028 loss = 1.7237e+05
# in step 1029 loss = 2.0373e+05
# in step 1030 loss = 2.0350e+05
# in step 1031 loss = 2.2157e+05
# in step 1032 loss = 2.6005e+05
# in step 1033 loss = 3.0373e+05
# in step 1034 loss = 2.2297e+05
# in step 1035 loss = 1.5758e+05
# in step 1036 loss = 2.6454e+05
# in step 1037 loss = 1.9315e+05
# in step 1038 loss = 2.4275e+05
# in step 1039 loss = 2.1150e+05
# in step 1040 loss = 2.0439e+05
# 2.6362e+01 sec took per 100steps
# in step 1041 loss = 2.6849e+05
# in step 1042 loss = 2.4527e+05
# in step 1043 loss = 2.0631e+05
# in step 1044 loss = 2.4687e+05
# in step 1045 loss = 2.0287e+05
# in step 1046 loss = 3.5991e+05
# in step 1047 loss = 2.4611e+05
# in step 1048 loss = 2.0951e+05
# in step 1049 loss = 2.8763e+05
# in step 1050 loss = 2.1163e+05
# in step 1051 loss = 2.1014e+05
# in step 1052 loss = 2.6759e+05
# in step 1053 loss = 2.4834e+05
# in step 1054 loss = 2.1172e+05
# in step 1055 loss = 2.4892e+05
# in step 1056 loss = 2.2531e+05
# in step 1057 loss = 2.4465e+05
# in step 1058 loss = 2.6217e+05
# in step 1059 loss = 2.6326e+05
# in step 1060 loss = 2.3990e+05
# in step 1061 loss = 2.0651e+05
# in step 1062 loss = 2.6268e+05
# in step 1063 loss = 1.7929e+05
# in step 1064 loss = 2.6038e+05
# in step 1065 loss = 2.2302e+05
# in step 1066 loss = 1.7280e+05
# in step 1067 loss = 1.8979e+05
# in step 1068 loss = 1.4688e+05
# in step 1069 loss = 2.6169e+05
# in step 1070 loss = 2.2432e+05
# in step 1071 loss = 2.5960e+05
# in step 1072 loss = 2.3888e+05
# in step 1073 loss = 1.7082e+05
# in step 1074 loss = 2.4093e+05
# in step 1075 loss = 2.7840e+05
# in step 1076 loss = 2.0919e+05
# in step 1077 loss = 2.5926e+05
# in step 1078 loss = 1.8643e+05
# in step 1079 loss = 1.7214e+05
# in step 1080 loss = 2.2149e+05
# 2.6639e+01 sec took per 100steps
# in step 1081 loss = 1.8652e+05
# in step 1082 loss = 2.0342e+05
# in step 1083 loss = 2.3767e+05
# in step 1084 loss = 2.5802e+05
# in step 1085 loss = 2.0125e+05
# in step 1086 loss = 2.0122e+05
# in step 1087 loss = 2.1865e+05
# in step 1088 loss = 2.3655e+05
# in step 1089 loss = 2.0081e+05
# in step 1090 loss = 2.5588e+05
# in step 1091 loss = 2.5551e+05
# in step 1092 loss = 2.1746e+05
# in step 1093 loss = 2.3601e+05
# in step 1094 loss = 1.8500e+05
# in step 1095 loss = 2.3555e+05
# in step 1096 loss = 2.0034e+05
# in step 1097 loss = 2.5400e+05
# in step 1098 loss = 2.0161e+05
# in step 1099 loss = 2.5509e+05
# in step 1100 loss = 1.8456e+05
# in step 1101 loss = 1.8419e+05
# in step 1102 loss = 2.5452e+05
# in step 1103 loss = 2.0017e+05
# in step 1104 loss = 1.9939e+05
# in step 1105 loss = 1.6850e+05
# in step 1106 loss = 1.6812e+05
# in step 1107 loss = 1.8297e+05
# in step 1108 loss = 2.5494e+05
# in step 1109 loss = 2.5651e+05
# in step 1110 loss = 2.9823e+05
# in step 1111 loss = 2.7945e+05
# in step 1112 loss = 2.3610e+05
# in step 1113 loss = 1.5658e+05
# in step 1114 loss = 2.0333e+05
# in step 1115 loss = 2.7534e+05
# in step 1116 loss = 1.7613e+05
# in step 1117 loss = 2.7705e+05
# in step 1118 loss = 2.9701e+05
# in step 1119 loss = 2.3920e+05
# in step 1120 loss = 2.7456e+05
# 2.6414e+01 sec took per 100steps
# in step 1121 loss = 2.2220e+05
# in step 1122 loss = 2.7425e+05
# in step 1123 loss = 2.3936e+05
# in step 1124 loss = 2.1881e+05
# in step 1125 loss = 2.0224e+05
# in step 1126 loss = 2.9859e+05
# in step 1127 loss = 2.7678e+05
# in step 1128 loss = 1.8837e+05
# in step 1129 loss = 2.2004e+05
# in step 1130 loss = 2.1903e+05
# in step 1131 loss = 2.0322e+05
# in step 1132 loss = 2.1789e+05
# in step 1133 loss = 2.0104e+05
# in step 1134 loss = 1.7044e+05
# in step 1135 loss = 2.3489e+05
# in step 1136 loss = 2.5343e+05
# in step 1137 loss = 2.3469e+05
# in step 1138 loss = 2.3354e+05
# in step 1139 loss = 1.8356e+05
# in step 1140 loss = 1.8372e+05
# in step 1141 loss = 1.8364e+05
# in step 1142 loss = 1.9847e+05
# in step 1143 loss = 2.3292e+05
# in step 1144 loss = 2.1607e+05
# in step 1145 loss = 1.9829e+05
# in step 1146 loss = 2.3433e+05
# in step 1147 loss = 2.5255e+05
# in step 1148 loss = 2.3422e+05
# in step 1149 loss = 1.9968e+05
# in step 1150 loss = 1.9829e+05
# in step 1151 loss = 1.9929e+05
# in step 1152 loss = 1.6806e+05
# in step 1153 loss = 1.9891e+05
# in step 1154 loss = 2.1516e+05
# in step 1155 loss = 1.9869e+05
# in step 1156 loss = 2.1646e+05
# in step 1157 loss = 1.9754e+05
# in step 1158 loss = 1.9818e+05
# in step 1159 loss = 1.9793e+05
# in step 1160 loss = 1.9672e+05
# 2.6383e+01 sec took per 100steps
# in step 1161 loss = 2.5255e+05
# in step 1162 loss = 2.7161e+05
# in step 1163 loss = 2.7165e+05
# in step 1164 loss = 1.9844e+05
# in step 1165 loss = 1.9892e+05
# in step 1166 loss = 1.8310e+05
# in step 1167 loss = 1.9703e+05
# in step 1168 loss = 2.3216e+05
# in step 1169 loss = 2.1489e+05
# in step 1170 loss = 1.9727e+05
# in step 1171 loss = 2.3336e+05
# in step 1172 loss = 2.1492e+05
# in step 1173 loss = 2.9240e+05
# in step 1174 loss = 2.3380e+05
# in step 1175 loss = 1.9832e+05
# in step 1176 loss = 2.1829e+05
# in step 1177 loss = 2.3310e+05
# in step 1178 loss = 2.5283e+05
# in step 1179 loss = 2.3329e+05
# in step 1180 loss = 1.9759e+05
# in step 1181 loss = 2.1778e+05
# in step 1182 loss = 1.6907e+05
# in step 1183 loss = 2.1529e+05
# in step 1184 loss = 2.3258e+05
# in step 1185 loss = 1.8241e+05
# in step 1186 loss = 2.5521e+05
# in step 1187 loss = 2.0277e+05
# in step 1188 loss = 1.8298e+05
# in step 1189 loss = 2.1716e+05
# in step 1190 loss = 1.6695e+05
# in step 1191 loss = 2.5690e+05
# in step 1192 loss = 2.0240e+05
# in step 1193 loss = 2.9463e+05
# in step 1194 loss = 2.9739e+05
# in step 1195 loss = 2.3341e+05
# in step 1196 loss = 1.5433e+05
# in step 1197 loss = 2.3838e+05
# in step 1198 loss = 2.1570e+05
# in step 1199 loss = 2.3572e+05
# in step 1200 loss = 1.6851e+05
# 2.6444e+01 sec took per 100steps
# in step 1201 loss = 2.0268e+05
# in step 1202 loss = 2.1579e+05
# in step 1203 loss = 2.3477e+05
# in step 1204 loss = 2.1552e+05
# in step 1205 loss = 2.3627e+05
# in step 1206 loss = 1.9721e+05
# in step 1207 loss = 2.3258e+05
# in step 1208 loss = 1.8221e+05
# in step 1209 loss = 1.6894e+05
# in step 1210 loss = 1.8351e+05
# in step 1211 loss = 2.1439e+05
# in step 1212 loss = 2.5169e+05
# in step 1213 loss = 1.8241e+05
# in step 1214 loss = 2.0253e+05
# in step 1215 loss = 2.5516e+05
# in step 1216 loss = 1.8542e+05
# in step 1217 loss = 2.5592e+05
# in step 1218 loss = 2.3596e+05
# in step 1219 loss = 2.3784e+05
# in step 1220 loss = 2.3440e+05
# in step 1221 loss = 2.1854e+05
# in step 1222 loss = 2.1514e+05
# in step 1223 loss = 1.8311e+05
# in step 1224 loss = 2.5548e+05
# in step 1225 loss = 2.2272e+05
# in step 1226 loss = 2.9331e+05
# in step 1227 loss = 2.0042e+05
# in step 1228 loss = 2.0196e+05
# in step 1229 loss = 1.6836e+05
# in step 1230 loss = 1.8242e+05
# in step 1231 loss = 2.1604e+05
# in step 1232 loss = 2.3180e+05
# in step 1233 loss = 1.9937e+05
# in step 1234 loss = 2.3323e+05
# in step 1235 loss = 2.3130e+05
# in step 1236 loss = 1.9964e+05
# in step 1237 loss = 2.1355e+05
# in step 1238 loss = 2.7218e+05
# in step 1239 loss = 2.1753e+05
# in step 1240 loss = 1.8272e+05
# 2.6391e+01 sec took per 100steps
# in step 1241 loss = 2.0068e+05
# in step 1242 loss = 2.1590e+05
# in step 1243 loss = 1.7039e+05
# in step 1244 loss = 1.8471e+05
# in step 1245 loss = 2.3490e+05
# in step 1246 loss = 2.0392e+05
# in step 1247 loss = 2.5348e+05
# in step 1248 loss = 1.8121e+05
# in step 1249 loss = 1.8085e+05
# in step 1250 loss = 1.6654e+05
# in step 1251 loss = 2.3116e+05
# in step 1252 loss = 2.1441e+05
# in step 1253 loss = 2.3047e+05
# in step 1254 loss = 1.8067e+05
# in step 1255 loss = 2.5072e+05
# in step 1256 loss = 2.6971e+05
# in step 1257 loss = 2.1661e+05
# in step 1258 loss = 1.6448e+05
# in step 1259 loss = 2.2043e+05
# in step 1260 loss = 2.4825e+05
# in step 1261 loss = 2.5591e+05
# in step 1262 loss = 2.1333e+05
# in step 1263 loss = 2.5780e+05
# in step 1264 loss = 1.6626e+05
# in step 1265 loss = 2.6903e+05
# in step 1266 loss = 2.1647e+05
# in step 1267 loss = 1.8163e+05
# in step 1268 loss = 1.8414e+05
# in step 1269 loss = 1.9720e+05
# in step 1270 loss = 1.9860e+05
# in step 1271 loss = 2.4911e+05
# in step 1272 loss = 2.1211e+05
# in step 1273 loss = 2.7101e+05
# in step 1274 loss = 1.8363e+05
# in step 1275 loss = 1.9704e+05
# in step 1276 loss = 1.4243e+05
# in step 1277 loss = 2.4202e+05
# in step 1278 loss = 1.9703e+05
# in step 1279 loss = 2.0254e+05
# in step 1280 loss = 2.3279e+05
# 2.6631e+01 sec took per 100steps
# in step 1281 loss = 2.1625e+05
# in step 1282 loss = 2.3414e+05
# in step 1283 loss = 2.4926e+05
# in step 1284 loss = 2.3563e+05
# in step 1285 loss = 2.1366e+05
# in step 1286 loss = 2.3252e+05
# in step 1287 loss = 1.8426e+05
# in step 1288 loss = 2.1231e+05
# in step 1289 loss = 2.2996e+05
# in step 1290 loss = 2.4932e+05
# in step 1291 loss = 2.1276e+05
# in step 1292 loss = 2.3034e+05
# in step 1293 loss = 2.3087e+05
# in step 1294 loss = 1.6663e+05
# in step 1295 loss = 1.8231e+05
# in step 1296 loss = 1.9688e+05
# in step 1297 loss = 2.6694e+05
# in step 1298 loss = 2.3313e+05
# in step 1299 loss = 2.8979e+05
# in step 1300 loss = 1.8129e+05
# in step 1301 loss = 2.4897e+05
# in step 1302 loss = 2.4518e+05
# in step 1303 loss = 1.9877e+05
# in step 1304 loss = 2.2882e+05
# in step 1305 loss = 1.9671e+05
# in step 1306 loss = 2.1051e+05
# in step 1307 loss = 1.9656e+05
# in step 1308 loss = 1.9436e+05
# in step 1309 loss = 1.9522e+05
# in step 1310 loss = 2.1053e+05
# in step 1311 loss = 2.2690e+05
# in step 1312 loss = 1.8109e+05
# in step 1313 loss = 2.6758e+05
# in step 1314 loss = 1.6820e+05
# in step 1315 loss = 2.4753e+05
# in step 1316 loss = 1.9606e+05
# in step 1317 loss = 2.5087e+05
# in step 1318 loss = 1.7963e+05
# in step 1319 loss = 2.1142e+05
# in step 1320 loss = 2.4793e+05
# 2.6251e+01 sec took per 100steps
# in step 1321 loss = 2.1208e+05
# in step 1322 loss = 2.0949e+05
# in step 1323 loss = 1.9571e+05
# in step 1324 loss = 1.6450e+05
# in step 1325 loss = 2.8844e+05
# in step 1326 loss = 1.8152e+05
# in step 1327 loss = 1.9648e+05
# in step 1328 loss = 2.1239e+05
# in step 1329 loss = 2.2883e+05
# in step 1330 loss = 2.4823e+05
# in step 1331 loss = 2.2783e+05
# in step 1332 loss = 2.2714e+05
# in step 1333 loss = 2.2846e+05
# in step 1334 loss = 2.2683e+05
# in step 1335 loss = 2.1039e+05
# in step 1336 loss = 2.2638e+05
# in step 1337 loss = 2.6541e+05
# in step 1338 loss = 2.1052e+05
# in step 1339 loss = 2.2639e+05
# in step 1340 loss = 1.6743e+05
# in step 1341 loss = 2.2874e+05
# in step 1342 loss = 2.0933e+05
# in step 1343 loss = 2.0972e+05
# in step 1344 loss = 1.9372e+05
# in step 1345 loss = 2.8482e+05
# in step 1346 loss = 2.6382e+05
# in step 1347 loss = 1.9510e+05
# in step 1348 loss = 1.7998e+05
# in step 1349 loss = 2.0966e+05
# in step 1350 loss = 2.4420e+05
# in step 1351 loss = 1.9483e+05
# in step 1352 loss = 2.1239e+05
# in step 1353 loss = 1.5502e+05
# in step 1354 loss = 2.0997e+05
# in step 1355 loss = 1.9306e+05
# in step 1356 loss = 2.2650e+05
# in step 1357 loss = 1.6494e+05
# in step 1358 loss = 3.0893e+05
# in step 1359 loss = 2.1117e+05
# in step 1360 loss = 2.0966e+05
# 2.6368e+01 sec took per 100steps
# in step 1361 loss = 2.6445e+05
# in step 1362 loss = 2.6879e+05
# in step 1363 loss = 2.0057e+05
# in step 1364 loss = 2.5428e+05
# in step 1365 loss = 2.1908e+05
# in step 1366 loss = 2.0171e+05
# in step 1367 loss = 2.5111e+05
# in step 1368 loss = 1.8123e+05
# in step 1369 loss = 2.4929e+05
# in step 1370 loss = 2.6795e+05
# in step 1371 loss = 1.8550e+05
# in step 1372 loss = 2.4791e+05
# in step 1373 loss = 2.3019e+05
# in step 1374 loss = 2.1323e+05
# in step 1375 loss = 1.6596e+05
# in step 1376 loss = 1.8249e+05
# in step 1377 loss = 1.7897e+05
# in step 1378 loss = 2.2786e+05
# in step 1379 loss = 2.2979e+05
# in step 1380 loss = 2.2517e+05
# in step 1381 loss = 1.9384e+05
# in step 1382 loss = 2.0849e+05
# in step 1383 loss = 1.6838e+05
# in step 1384 loss = 2.5557e+05
# in step 1385 loss = 2.1105e+05
# in step 1386 loss = 1.9965e+05
# in step 1387 loss = 2.4519e+05
# in step 1388 loss = 2.3121e+05
# in step 1389 loss = 2.0858e+05
# in step 1390 loss = 1.9562e+05
# in step 1391 loss = 2.0882e+05
# in step 1392 loss = 2.4434e+05
# in step 1393 loss = 2.2466e+05
# in step 1394 loss = 2.2602e+05
# in step 1395 loss = 1.6563e+05
# in step 1396 loss = 1.9223e+05
# in step 1397 loss = 1.4057e+05
# in step 1398 loss = 2.4880e+05
# in step 1399 loss = 1.9934e+05
# in step 1400 loss = 2.2800e+05
# 2.6540e+01 sec took per 100steps
# in step 1401 loss = 2.4766e+05
# in step 1402 loss = 1.8376e+05
# in step 1403 loss = 2.0871e+05
# in step 1404 loss = 1.6578e+05
# in step 1405 loss = 1.9294e+05
# in step 1406 loss = 2.6495e+05
# in step 1407 loss = 2.0947e+05
# in step 1408 loss = 2.1005e+05
# in step 1409 loss = 1.7726e+05
# in step 1410 loss = 2.0891e+05
# in step 1411 loss = 1.9200e+05
# in step 1412 loss = 1.9257e+05
# in step 1413 loss = 1.9060e+05
# in step 1414 loss = 1.9174e+05
# in step 1415 loss = 1.7529e+05
# in step 1416 loss = 2.4442e+05
# in step 1417 loss = 2.6278e+05
# in step 1418 loss = 1.9203e+05
# in step 1419 loss = 2.0953e+05
# in step 1420 loss = 1.6113e+05
# in step 1421 loss = 1.9062e+05
# in step 1422 loss = 2.6209e+05
# in step 1423 loss = 2.4046e+05
# in step 1424 loss = 1.6400e+05
# in step 1425 loss = 2.4689e+05
# in step 1426 loss = 2.4213e+05
# in step 1427 loss = 2.2532e+05
# in step 1428 loss = 1.7753e+05
# in step 1429 loss = 2.0972e+05
# in step 1430 loss = 2.2586e+05
# in step 1431 loss = 1.9338e+05
# in step 1432 loss = 1.9294e+05
# in step 1433 loss = 2.0879e+05
# in step 1434 loss = 1.7946e+05
# in step 1435 loss = 2.6140e+05
# in step 1436 loss = 1.7545e+05
# in step 1437 loss = 1.9170e+05
# in step 1438 loss = 1.9099e+05
# in step 1439 loss = 2.0653e+05
# in step 1440 loss = 2.0628e+05
# 2.6419e+01 sec took per 100steps
# in step 1441 loss = 2.6210e+05
# in step 1442 loss = 2.0783e+05
# in step 1443 loss = 2.2310e+05
# in step 1444 loss = 2.0581e+05
# in step 1445 loss = 1.7579e+05
# in step 1446 loss = 2.0501e+05
# in step 1447 loss = 1.8929e+05
# in step 1448 loss = 2.0546e+05
# in step 1449 loss = 2.5917e+05
# in step 1450 loss = 1.9232e+05
# in step 1451 loss = 2.4152e+05
# in step 1452 loss = 2.0634e+05
# in step 1453 loss = 1.8997e+05
# in step 1454 loss = 2.2272e+05
# in step 1455 loss = 2.3868e+05
# in step 1456 loss = 2.5934e+05
# in step 1457 loss = 1.9014e+05
# in step 1458 loss = 2.2310e+05
# in step 1459 loss = 2.5774e+05
# in step 1460 loss = 2.4101e+05
# in step 1461 loss = 1.9098e+05
# in step 1462 loss = 2.0567e+05
# in step 1463 loss = 2.2306e+05
# in step 1464 loss = 2.2133e+05
# in step 1465 loss = 2.5858e+05
# in step 1466 loss = 2.2145e+05
# in step 1467 loss = 1.7790e+05
# in step 1468 loss = 3.0655e+05
# in step 1469 loss = 2.3391e+05
# in step 1470 loss = 1.9980e+05
# in step 1471 loss = 2.1261e+05
# in step 1472 loss = 1.8393e+05
# in step 1473 loss = 2.2626e+05
# in step 1474 loss = 1.9698e+05
# in step 1475 loss = 1.6746e+05
# in step 1476 loss = 2.2708e+05
# in step 1477 loss = 2.0812e+05
# in step 1478 loss = 2.1037e+05
# in step 1479 loss = 1.9008e+05
# in step 1480 loss = 2.2571e+05
# 2.6322e+01 sec took per 100steps
# in step 1481 loss = 2.2184e+05
# in step 1482 loss = 1.7659e+05
# in step 1483 loss = 2.0606e+05
# in step 1484 loss = 1.7767e+05
# in step 1485 loss = 2.0683e+05
# in step 1486 loss = 1.7405e+05
# in step 1487 loss = 1.7484e+05
# in step 1488 loss = 1.8873e+05
# in step 1489 loss = 1.7290e+05
# in step 1490 loss = 2.0503e+05
# in step 1491 loss = 1.8793e+05
# in step 1492 loss = 1.4133e+05
# in step 1493 loss = 2.0935e+05
# in step 1494 loss = 1.4788e+05
# in step 1495 loss = 2.0818e+05
# in step 1496 loss = 1.7332e+05
# in step 1497 loss = 2.4166e+05
# in step 1498 loss = 1.8927e+05
# in step 1499 loss = 1.8829e+05
# in step 1500 loss = 1.7392e+05
# in step 1501 loss = 1.8813e+05
# in step 1502 loss = 2.3999e+05
# in step 1503 loss = 1.6170e+05
# in step 1504 loss = 2.2334e+05
# in step 1505 loss = 2.4040e+05
# in step 1506 loss = 2.2281e+05
# in step 1507 loss = 2.4130e+05
# in step 1508 loss = 2.2035e+05
# in step 1509 loss = 2.2146e+05
# in step 1510 loss = 2.2095e+05
# in step 1511 loss = 1.6153e+05
# in step 1512 loss = 1.8990e+05
# ...
# in step 6902 loss = 1.2285e+05
# in step 6903 loss = 1.2999e+05
# in step 6904 loss = 1.1769e+05
# in step 6905 loss = 1.2892e+05
# in step 6906 loss = 1.3101e+05
# in step 6907 loss = 1.1972e+05
# in step 6908 loss = 1.4976e+05
# in step 6909 loss = 1.4529e+05
# in step 6910 loss = 1.2492e+05
# in step 6911 loss = 1.3740e+05
# in step 6912 loss = 1.2029e+05
# in step 6913 loss = 1.3199e+05
# in step 6914 loss = 1.2371e+05
# in step 6915 loss = 1.5952e+05
# in step 6916 loss = 1.3156e+05
# in step 6917 loss = 1.2903e+05
# in step 6918 loss = 1.4777e+05
# in step 6919 loss = 1.3665e+05
# in step 6920 loss = 1.1633e+05
# 2.6572e+01 sec took per 100steps
# old loss=1.4985e+05 , new loss=1.3804e+05
# in step 6921 loss = 1.3802e+05
# in step 6922 loss = 1.1946e+05
# in step 6923 loss = 1.3837e+05
# in step 6924 loss = 1.3173e+05
# in step 6925 loss = 1.3043e+05
# in step 6926 loss = 1.1734e+05
# in step 6927 loss = 1.7213e+05
# in step 6928 loss = 1.1629e+05
# in step 6929 loss = 1.3446e+05
# in step 6930 loss = 1.2189e+05
# in step 6931 loss = 1.2491e+05
# in step 6932 loss = 1.5796e+05
# in step 6933 loss = 1.2863e+05
# in step 6934 loss = 1.4037e+05
# in step 6935 loss = 1.3728e+05
# in step 6936 loss = 1.3249e+05
# in step 6937 loss = 1.3308e+05
# in step 6938 loss = 1.2878e+05
# in step 6939 loss = 1.2846e+05
# in step 6940 loss = 1.3029e+05
# in step 6941 loss = 1.1594e+05
# in step 6942 loss = 1.2453e+05
# in step 6943 loss = 1.3829e+05
# in step 6944 loss = 1.2436e+05
# in step 6945 loss = 1.2133e+05
# in step 6946 loss = 1.2341e+05
# in step 6947 loss = 1.3767e+05
# in step 6948 loss = 1.3570e+05
# in step 6949 loss = 1.2022e+05
# in step 6950 loss = 1.2908e+05
# in step 6951 loss = 1.1903e+05
# in step 6952 loss = 1.1831e+05
# in step 6953 loss = 1.1737e+05
# in step 6954 loss = 1.3157e+05
# in step 6955 loss = 1.4677e+05
# in step 6956 loss = 1.2140e+05
# in step 6957 loss = 1.1905e+05
# in step 6958 loss = 1.1443e+05
# in step 6959 loss = 1.5795e+05
# in step 6960 loss = 1.2128e+05
# 2.6516e+01 sec took per 100steps
# old loss=1.4933e+05 , new loss=1.3777e+05
# in step 6961 loss = 1.1886e+05
# in step 6962 loss = 1.1328e+05
# in step 6963 loss = 1.2462e+05
# in step 6964 loss = 1.7280e+05
# in step 6965 loss = 1.3961e+05
# in step 6966 loss = 1.1703e+05
# in step 6967 loss = 1.3183e+05
# in step 6968 loss = 1.5554e+05
# in step 6969 loss = 1.3989e+05
# in step 6970 loss = 1.5523e+05
# in step 6971 loss = 1.3646e+05
# in step 6972 loss = 1.4492e+05
# in step 6973 loss = 1.3037e+05
# in step 6974 loss = 1.4464e+05
# in step 6975 loss = 1.4211e+05
# in step 6976 loss = 1.3341e+05
# in step 6977 loss = 1.2701e+05
# in step 6978 loss = 1.2254e+05
# in step 6979 loss = 1.2578e+05
# in step 6980 loss = 1.3312e+05
# in step 6981 loss = 1.2018e+05
# in step 6982 loss = 1.1440e+05
# in step 6983 loss = 1.2322e+05
# in step 6984 loss = 1.6684e+05
# in step 6985 loss = 1.3119e+05
# in step 6986 loss = 1.4338e+05
# in step 6987 loss = 1.1865e+05
# in step 6988 loss = 1.2226e+05
# in step 6989 loss = 1.2615e+05
# in step 6990 loss = 1.2568e+05
# in step 6991 loss = 1.3307e+05
# in step 6992 loss = 1.3315e+05
# in step 6993 loss = 1.2526e+05
# in step 6994 loss = 1.5499e+05
# in step 6995 loss = 1.5379e+05
# in step 6996 loss = 1.2684e+05
# in step 6997 loss = 1.4296e+05
# in step 6998 loss = 1.4373e+05
# in step 6999 loss = 1.2770e+05
# in step 7000 loss = 1.3325e+05
# 2.6379e+01 sec took per 100steps
# old loss=1.4849e+05 , new loss=1.3769e+05
# in step 7001 loss = 1.2601e+05
# in step 7002 loss = 1.6669e+05
# in step 7003 loss = 1.3525e+05
# in step 7004 loss = 1.4203e+05
# in step 7005 loss = 1.1613e+05
# in step 7006 loss = 1.5006e+05
# in step 7007 loss = 1.3514e+05
# in step 7008 loss = 1.3174e+05
# in step 7009 loss = 1.4227e+05
# in step 7010 loss = 1.3658e+05
# in step 7011 loss = 1.3904e+05
# in step 7012 loss = 1.1886e+05
# in step 7013 loss = 1.3267e+05
# in step 7014 loss = 1.1789e+05
# in step 7015 loss = 1.3615e+05
# in step 7016 loss = 1.4507e+05
# in step 7017 loss = 1.2479e+05
# in step 7018 loss = 1.3799e+05
# in step 7019 loss = 1.1838e+05
# in step 7020 loss = 1.3645e+05
# in step 7021 loss = 1.3880e+05
# in step 7022 loss = 1.2869e+05
# in step 7023 loss = 1.2136e+05
# in step 7024 loss = 1.1767e+05
# in step 7025 loss = 1.4836e+05
# in step 7026 loss = 1.3832e+05
# in step 7027 loss = 1.2322e+05
# in step 7028 loss = 1.1850e+05
# in step 7029 loss = 1.4634e+05
# in step 7030 loss = 1.4734e+05
# in step 7031 loss = 1.1429e+05
# in step 7032 loss = 1.3188e+05
# in step 7033 loss = 1.1531e+05
# in step 7034 loss = 1.3896e+05
# in step 7035 loss = 1.3630e+05
# in step 7036 loss = 1.4582e+05
# in step 7037 loss = 1.2421e+05
# in step 7038 loss = 1.4546e+05
# in step 7039 loss = 1.2812e+05
# in step 7040 loss = 1.4431e+05
# 2.6532e+01 sec took per 100steps
# old loss=1.4779e+05 , new loss=1.3745e+05
# in step 7041 loss = 1.1817e+05
# in step 7042 loss = 1.3052e+05
# in step 7043 loss = 1.2827e+05
# in step 7044 loss = 1.2818e+05
# in step 7045 loss = 1.3515e+05
# in step 7046 loss = 1.2007e+05
# in step 7047 loss = 1.2712e+05
# in step 7048 loss = 1.1609e+05
# in step 7049 loss = 1.2244e+05
# in step 7050 loss = 1.1963e+05
# in step 7051 loss = 1.1367e+05
# in step 7052 loss = 1.1667e+05
# in step 7053 loss = 1.1932e+05
# in step 7054 loss = 1.1262e+05
# in step 7055 loss = 1.1115e+05
# in step 7056 loss = 1.3577e+05
# in step 7057 loss = 1.3414e+05
# in step 7058 loss = 1.1151e+05
# in step 7059 loss = 1.1114e+05
# in step 7060 loss = 1.1521e+05
# in step 7061 loss = 1.2567e+05
# in step 7062 loss = 1.7233e+05
# in step 7063 loss = 1.1296e+05
# in step 7064 loss = 1.1055e+05
# in step 7065 loss = 1.0922e+05
# in step 7066 loss = 1.0871e+05
# in step 7067 loss = 1.1421e+05
# in step 7068 loss = 1.3004e+05
# in step 7069 loss = 1.2247e+05
# in step 7070 loss = 1.3683e+05
# in step 7071 loss = 1.1669e+05
# in step 7072 loss = 1.1695e+05
# in step 7073 loss = 1.2177e+05
# in step 7074 loss = 1.3557e+05
# in step 7075 loss = 1.4735e+05
# in step 7076 loss = 1.4626e+05
# in step 7077 loss = 1.1494e+05
# in step 7078 loss = 1.1108e+05
# in step 7079 loss = 1.2956e+05
# in step 7080 loss = 1.2647e+05
# 2.6569e+01 sec took per 100steps
# old loss=1.4715e+05 , new loss=1.3691e+05
# in step 7081 loss = 1.1286e+05
# in step 7082 loss = 1.4799e+05
# in step 7083 loss = 1.4557e+05
# in step 7084 loss = 1.1106e+05
# in step 7085 loss = 1.2396e+05
# in step 7086 loss = 1.5941e+05
# in step 7087 loss = 1.1897e+05
# in step 7088 loss = 1.2576e+05
# in step 7089 loss = 1.4667e+05
# in step 7090 loss = 1.3248e+05
# in step 7091 loss = 1.4664e+05
# in step 7092 loss = 1.1792e+05
# in step 7093 loss = 1.2677e+05
# in step 7094 loss = 1.5610e+05
# in step 7095 loss = 1.3764e+05
# in step 7096 loss = 1.4707e+05
# in step 7097 loss = 1.2656e+05
# in step 7098 loss = 1.2036e+05
# in step 7099 loss = 1.1599e+05
# in step 7100 loss = 1.1693e+05
# in step 7101 loss = 1.2020e+05
# in step 7102 loss = 1.1497e+05
# in step 7103 loss = 1.1835e+05
# in step 7104 loss = 1.2519e+05
# in step 7105 loss = 1.1602e+05
# in step 7106 loss = 1.1165e+05
# in step 7107 loss = 1.1171e+05
# in step 7108 loss = 1.1429e+05
# in step 7109 loss = 1.1400e+05
# in step 7110 loss = 1.2742e+05
# in step 7111 loss = 1.3704e+05
# in step 7112 loss = 1.3514e+05
# in step 7113 loss = 1.4394e+05
# in step 7114 loss = 1.7096e+05
# in step 7115 loss = 1.2108e+05
# in step 7116 loss = 1.3862e+05
# in step 7117 loss = 1.7000e+05
# in step 7118 loss = 1.1560e+05
# in step 7119 loss = 1.2643e+05
# in step 7120 loss = 1.5782e+05
# 2.6429e+01 sec took per 100steps
# old loss=1.4690e+05 , new loss=1.3644e+05
# in step 7121 loss = 1.4095e+05
# in step 7122 loss = 1.2879e+05
# in step 7123 loss = 1.4164e+05
# in step 7124 loss = 1.2219e+05
# in step 7125 loss = 1.6300e+05
# in step 7126 loss = 1.5643e+05
# in step 7127 loss = 1.2454e+05
# in step 7128 loss = 1.2451e+05
# in step 7129 loss = 1.1846e+05
# in step 7130 loss = 1.3478e+05
# in step 7131 loss = 1.2724e+05
# in step 7132 loss = 1.4212e+05
# in step 7133 loss = 1.1687e+05
# in step 7134 loss = 1.4903e+05
# in step 7135 loss = 1.4019e+05
# in step 7136 loss = 1.2988e+05
# in step 7137 loss = 1.7720e+05
# in step 7138 loss = 1.1322e+05
# in step 7139 loss = 1.6521e+05
# in step 7140 loss = 1.4407e+05
# in step 7141 loss = 1.2121e+05
# in step 7142 loss = 1.3767e+05
# in step 7143 loss = 1.2907e+05
# in step 7144 loss = 1.3529e+05
# in step 7145 loss = 1.1693e+05
# in step 7146 loss = 1.2941e+05
# in step 7147 loss = 1.3906e+05
# in step 7148 loss = 1.3282e+05
# in step 7149 loss = 1.3606e+05
# in step 7150 loss = 1.2202e+05
# in step 7151 loss = 1.2559e+05
# in step 7152 loss = 1.3018e+05
# in step 7153 loss = 1.4378e+05
# in step 7154 loss = 1.4262e+05
# in step 7155 loss = 1.2211e+05
# in step 7156 loss = 1.6743e+05
# in step 7157 loss = 1.2983e+05
# in step 7158 loss = 1.3886e+05
# in step 7159 loss = 1.2742e+05
# in step 7160 loss = 1.6569e+05
# 2.6452e+01 sec took per 100steps
# old loss=1.4671e+05 , new loss=1.3606e+05
# in step 7161 loss = 1.1354e+05
# in step 7162 loss = 1.5382e+05
# in step 7163 loss = 1.4121e+05
# in step 7164 loss = 1.2146e+05
# in step 7165 loss = 1.5329e+05
# in step 7166 loss = 1.8350e+05
# in step 7167 loss = 1.3266e+05
# in step 7168 loss = 1.5351e+05
# in step 7169 loss = 1.6830e+05
# in step 7170 loss = 1.4011e+05
# in step 7171 loss = 1.4925e+05
# in step 7172 loss = 1.2990e+05
# in step 7173 loss = 1.7782e+05
# in step 7174 loss = 1.3676e+05
# in step 7175 loss = 1.3762e+05
# in step 7176 loss = 1.8473e+05
# in step 7177 loss = 1.2958e+05
# in step 7178 loss = 2.3051e+05
# in step 7179 loss = 2.0926e+05
# in step 7180 loss = 1.6241e+05
# in step 7181 loss = 1.4172e+05
# in step 7182 loss = 1.6653e+05
# in step 7183 loss = 2.9830e+05
# in step 7184 loss = 2.5605e+05
# in step 7185 loss = 1.4225e+05
# in step 7186 loss = 1.7338e+05
# in step 7187 loss = 2.5513e+05
# in step 7188 loss = 1.8616e+05
# in step 7189 loss = 2.0147e+05
# in step 7190 loss = 2.1352e+05
# in step 7191 loss = 2.7621e+05
# in step 7192 loss = 1.4496e+05
# in step 7193 loss = 1.2975e+05
# in step 7194 loss = 1.5965e+05
# in step 7195 loss = 2.5020e+05
# in step 7196 loss = 2.7813e+05
# in step 7197 loss = 1.8150e+05
# in step 7198 loss = 1.8180e+05
# in step 7199 loss = 2.6358e+05
# in step 7200 loss = 2.0001e+05
# 2.6523e+01 sec took per 100steps
# old loss=1.4623e+05 , new loss=1.3757e+05
# in step 7201 loss = 1.8896e+05
# in step 7202 loss = 1.7302e+05
# in step 7203 loss = 1.6611e+05
# in step 7204 loss = 2.4184e+05
# in step 7205 loss = 3.1016e+05
# in step 7206 loss = 1.8988e+05
# in step 7207 loss = 1.7261e+05
# in step 7208 loss = 1.8487e+05
# in step 7209 loss = 2.7817e+05
# in step 7210 loss = 1.7333e+05
# in step 7211 loss = 3.1957e+05
# in step 7212 loss = 2.6038e+05
# in step 7213 loss = 2.8837e+05
# in step 7214 loss = 2.8968e+05
# in step 7215 loss = 2.8783e+05
# in step 7216 loss = 2.8964e+05
# in step 7217 loss = 2.6676e+05
# in step 7218 loss = 3.6037e+05
# in step 7219 loss = 4.8058e+05
# in step 7220 loss = 3.2457e+05
# in step 7221 loss = 3.2784e+05
# in step 7222 loss = 2.8070e+05
# in step 7223 loss = 2.4874e+05
# in step 7224 loss = 2.5274e+05
# in step 7225 loss = 2.6223e+05
# in step 7226 loss = 2.8139e+05
# in step 7227 loss = 3.0517e+05
# in step 7228 loss = 1.9373e+05
# in step 7229 loss = 2.8979e+05
# in step 7230 loss = 2.1718e+05
# in step 7231 loss = 2.6640e+05
# in step 7232 loss = 1.9682e+05
# in step 7233 loss = 2.0192e+05
# in step 7234 loss = 1.9514e+05
# in step 7235 loss = 2.6190e+05
# in step 7236 loss = 2.3124e+05
# in step 7237 loss = 2.0585e+05
# in step 7238 loss = 2.3321e+05
# in step 7239 loss = 1.6866e+05
# in step 7240 loss = 2.2086e+05
# 2.6415e+01 sec took per 100steps
# old loss=1.4566e+05 , new loss=1.4230e+05
# in step 7241 loss = 1.5716e+05
# in step 7242 loss = 2.6112e+05
# in step 7243 loss = 1.7865e+05
# in step 7244 loss = 2.7723e+05
# in step 7245 loss = 2.3123e+05
# in step 7246 loss = 1.9897e+05
# in step 7247 loss = 2.2696e+05
# in step 7248 loss = 2.1039e+05
# in step 7249 loss = 2.1010e+05
# in step 7250 loss = 2.0127e+05
# in step 7251 loss = 1.6559e+05
# in step 7252 loss = 1.5894e+05
# in step 7253 loss = 1.7623e+05
# in step 7254 loss = 1.4822e+05
# in step 7255 loss = 2.3716e+05
# in step 7256 loss = 1.8775e+05
# in step 7257 loss = 1.3926e+05
# in step 7258 loss = 1.5355e+05
# in step 7259 loss = 1.5523e+05
# in step 7260 loss = 1.8419e+05
# in step 7261 loss = 1.7844e+05
# in step 7262 loss = 1.4123e+05
# in step 7263 loss = 1.6521e+05
# in step 7264 loss = 1.4875e+05
# in step 7265 loss = 1.3146e+05
# in step 7266 loss = 1.6414e+05
# in step 7267 loss = 1.2630e+05
# in step 7268 loss = 1.4489e+05
# in step 7269 loss = 1.7389e+05
# in step 7270 loss = 1.3030e+05
# in step 7271 loss = 1.6126e+05
# in step 7272 loss = 1.2895e+05
# in step 7273 loss = 1.3003e+05
# in step 7274 loss = 1.5545e+05
# in step 7275 loss = 1.3798e+05
# in step 7276 loss = 1.8016e+05
# in step 7277 loss = 1.1707e+05
# in step 7278 loss = 1.2256e+05
# in step 7279 loss = 1.2945e+05
# in step 7280 loss = 1.2871e+05
# 2.6481e+01 sec took per 100steps
# old loss=1.4516e+05 , new loss=1.4370e+05
# in step 7281 loss = 1.3555e+05
# in step 7282 loss = 1.3230e+05
# in step 7283 loss = 1.3386e+05
# in step 7284 loss = 1.3141e+05
# in step 7285 loss = 1.2043e+05
# in step 7286 loss = 1.5344e+05
# in step 7287 loss = 1.3017e+05
# in step 7288 loss = 1.3900e+05
# in step 7289 loss = 1.1850e+05
# in step 7290 loss = 1.3109e+05
# in step 7291 loss = 1.3169e+05
# in step 7292 loss = 1.2778e+05
# in step 7293 loss = 1.3068e+05
# in step 7294 loss = 1.4552e+05
# in step 7295 loss = 1.3701e+05
# in step 7296 loss = 1.2968e+05
# in step 7297 loss = 1.5673e+05
# in step 7298 loss = 1.2554e+05
# in step 7299 loss = 1.4811e+05
# in step 7300 loss = 1.2945e+05
# in step 7301 loss = 1.4808e+05
# in step 7302 loss = 1.2220e+05
# in step 7303 loss = 1.6357e+05
# in step 7304 loss = 1.1832e+05
# in step 7305 loss = 1.2215e+05
# in step 7306 loss = 1.2676e+05
# in step 7307 loss = 1.2859e+05
# in step 7308 loss = 1.3780e+05
# in step 7309 loss = 1.1459e+05
# in step 7310 loss = 1.2527e+05
# in step 7311 loss = 1.4676e+05
# in step 7312 loss = 1.4619e+05
# in step 7313 loss = 1.3595e+05
# in step 7314 loss = 1.1812e+05
# in step 7315 loss = 1.2996e+05
# in step 7316 loss = 1.4534e+05
# in step 7317 loss = 1.2466e+05
# in step 7318 loss = 1.2323e+05
# in step 7319 loss = 1.2872e+05
# in step 7320 loss = 1.3611e+05
# 2.6430e+01 sec took per 100steps
# old loss=1.4477e+05 , new loss=1.4360e+05
# in step 7321 loss = 1.1616e+05
# in step 7322 loss = 1.5051e+05
# in step 7323 loss = 1.2703e+05
# in step 7324 loss = 1.1901e+05
# in step 7325 loss = 1.3609e+05
# in step 7326 loss = 1.1756e+05
# in step 7327 loss = 1.2880e+05
# in step 7328 loss = 1.2077e+05
# in step 7329 loss = 1.1627e+05
# in step 7330 loss = 1.3654e+05
# in step 7331 loss = 1.2155e+05
# in step 7332 loss = 1.1688e+05
# in step 7333 loss = 1.2103e+05
# in step 7334 loss = 1.1210e+05
# in step 7335 loss = 1.5891e+05
# in step 7336 loss = 1.5698e+05
# in step 7337 loss = 1.2776e+05
# in step 7338 loss = 1.3490e+05
# in step 7339 loss = 1.1379e+05
# in step 7340 loss = 1.1507e+05
# in step 7341 loss = 1.1318e+05
# in step 7342 loss = 1.4364e+05
# in step 7343 loss = 1.3558e+05
# in step 7344 loss = 1.2580e+05
# in step 7345 loss = 1.2717e+05
# in step 7346 loss = 1.2531e+05
# in step 7347 loss = 1.1972e+05
# in step 7348 loss = 1.3329e+05
# in step 7349 loss = 1.1502e+05
# in step 7350 loss = 1.3377e+05
# in step 7351 loss = 1.1892e+05
# in step 7352 loss = 1.3264e+05
# in step 7353 loss = 1.1538e+05
# in step 7354 loss = 1.2642e+05
# in step 7355 loss = 1.2645e+05
# in step 7356 loss = 1.3292e+05
# in step 7357 loss = 1.3268e+05
# in step 7358 loss = 1.4221e+05
# in step 7359 loss = 1.2514e+05
# in step 7360 loss = 1.3100e+05
# 2.7312e+01 sec took per 100steps
# old loss=1.4440e+05 , new loss=1.4276e+05
# in step 7361 loss = 1.3118e+05
# in step 7362 loss = 1.3899e+05
# in step 7363 loss = 1.2436e+05
# in step 7364 loss = 1.3950e+05
# in step 7365 loss = 1.6649e+05
# in step 7366 loss = 1.2526e+05
# in step 7367 loss = 1.4313e+05
# in step 7368 loss = 1.2096e+05
# in step 7369 loss = 1.2134e+05
# in step 7370 loss = 1.3996e+05
# in step 7371 loss = 1.1536e+05
# in step 7372 loss = 1.2772e+05
# in step 7373 loss = 1.2597e+05
# in step 7374 loss = 1.2243e+05
# in step 7375 loss = 1.2032e+05
# in step 7376 loss = 1.2009e+05
# in step 7377 loss = 1.3285e+05
# in step 7378 loss = 1.5340e+05
# in step 7379 loss = 1.4022e+05
# in step 7380 loss = 1.1350e+05
# in step 7381 loss = 1.4205e+05
# in step 7382 loss = 1.1652e+05
# in step 7383 loss = 1.8248e+05
# in step 7384 loss = 1.3439e+05
# in step 7385 loss = 1.2583e+05
# in step 7386 loss = 1.1269e+05
# in step 7387 loss = 1.3533e+05
# in step 7388 loss = 1.1672e+05
